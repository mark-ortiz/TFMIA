# %% [markdown]
# # NOTEBOOK PARA OBTENER LOS HITS Y MEJORES HITS
# Esto incluye la limpieza que se requiere ya que se tienen dobles espacios en cada línea.
#
# **Que pasos debo seguir para elegir todos los raw hits de acuerdo a lo indicado por Salva:**
#
# "...En realidad, hablando con mi hermano hemos decidido que los selected pulses no cal guardarlos, los usas para el match, y coges todos los hits que coincidan (cada uno de ellos será una nueva fila en tu CVS). Como decía antes, en las columnas tendrás toda la información del muón, del bbfit, del affit, y del hit coincidente con un selected pulse particular."
#
# El pseudocódigo que se me ocurre es el siguiente:
#
# 1. Seleccionar el primer "selected pulse" de la lista de seleccionados.
# 2. Filtrar el df de raw hits por todos los que coincidan en linea detector y piso detector.
# 3. Filtrar el resultado viendo cuales coinciden en los parámetrox X', Y', Z' y X, Y, Z.
# 4. Guardar el resultado en el dataframe final junto con runID, frameID
# 5. Iterar hasta que ya no haya mas selected pulses
# 6. Hacer lo mismo para cada evento del archivo seleccionado
#
# Actualización: Salva me mencionó en correo del día 3 Jul que se debe filtrar con respecto al piso_detector y línea_detector y quedarse con todos esos hits. Cito a la letra:
#
# "Perdón por el mareo. A ver, hablando con mi hermano me ha recordado que la forma que quedamos de hacerlo es con match de linea y piso del sensor, mas un cutoff de tiempo relativo respecto al selected pulse, que dijimos por ejemplo 50.
# Yo recomendaria este filtro ponerlo mas adelante y coger todos los raw hits qcoinciden en linia y piso, mas qnada porque ai queremos probar otro cutoff de 70 o 100, no tengamos que correr todo esto de nuevo..."
#
# Con base en esta nueva instrucción intentaré seleccionar de esta forma los best hits. (Sólo con linea y piso).
#
# Referencias:
# * https://cmdlinetips.com/2018/02/how-to-subset-pandas-dataframe-based-on-values-of-a-column/
#
# * https://medium.com/@juan.7655/cleansing-messy-excel-files-with-pandas-95a2ba3d8b2d
#
# * https://medium.com/dunder-data/pandas-challenge-2-explain-the-1-000x-speed-difference-when-taking-the-mean-35d72fe10c1

# %%
#### Primero algunas variables importantes de ubicación de los archivos y librerías ####

import os
import pandas as pd
import re
import math

#extractpath = "Z:\MASTER INT. ARTIFICIAL\TFM_DATA\TXTs" #Este es para mi no tan nueva PC-Desktop
#csv_path = "Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\\" #Path para mi PC Desktop

extractpath = "F:\\DATA_TFM\\TXTs" #Este path es para mi PC en el trabajo
csv_path = "F:\\DATA_TFM\\CSVs\\" #Path para mi PC en el trabajo

#extractpath = "U:\MASTER INT. ARTIFICIAL\TFM_DATA\TXTs" #Este path es para mi laptop en casa
#csv_path = "U:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\\" #Path para mi latptop en casa

txtfilesarr = os.listdir(extractpath); txtfilesarr = sorted(txtfilesarr)
csvarr = os.listdir(csv_path); csvarr = sorted(csvarr)

# %%
###############################
#### FUNCIONES IMPORTANTES ####
###############################

# Funcion para obtener los indices de un archivo
def indices(df):
    ind_startev = [];ind_runid = [];ind_weights = [];ind_muon = []
    ind_bbfit = [];ind_bb_selp = [];ind_endev = [];#ind_aafit = []
    for i in range(data.shape[0]):
        tempstr = data[0][i]
        if "start_event" in tempstr: ind_startev.append(i)
        if "UTC" in tempstr: ind_runid.append(i)
        if "weights" in tempstr: ind_weights.append(i)
        if "muon" in tempstr: ind_muon.append(i)
        #if "aafit" in tempstr:  ##NO LO CALCULARE!!! OBTENDRE LOS VALORES DE OTRA FORMA
        #    ind_aafit.append(i) ##COMO TENGO EL INDICE DE BBFIT, RESTO 1 LINEA Y ASIGNO VALORES
        if "bbfit" in tempstr:   ##SEGUN LA EXISTENCIA O NO DE LA LINEA!!!! EUREKA!!!
            ind_bbfit.append(i)
        if "selected" in tempstr: ind_bb_selp.append(i)
        if "end_event" in tempstr: ind_endev.append(i)
    return(ind_startev,ind_runid,ind_weights,ind_muon,ind_bbfit,ind_bb_selp,ind_endev)

#Función para limpiar un hit (lista) de elementos tipo dobles espacios y simples
def limpiahit(templist):
    cleanlist = []
    for j in range(len(templist)):
        if templist[j]!="":
            cleanlist.append(templist[j])
    return(cleanlist)

#Función para buscar los "rows" que coinciden en línea y piso de solo un selected pulse
def func_lineas_coinc(linea,piso,selp,hits):
    lineas_coinc = []
    for i in range(len(hits)):
        if hits[i][2]==linea and hits[i][3]==piso:
            lineas_coinc.append(hits_raw_limpios[i])
    return(lineas_coinc)

#Función para obtener todas las líneas de los selected pulse de un evento
def func_lineas_evento(sel_hits_limpios,hits_raw_limpios):
    lineas_selp_evento = []
    for i in range(len(sel_hits_limpios)):
        lindet = sel_hits_limpios[i][2] #Linea detector a buscar
        storey = sel_hits_limpios[i][3] #Piso detector a buscar
        lineas = func_lineas_coinc(lindet,storey,sel_hits_limpios[i],hits_raw_limpios)
        #Debo añadir las lineas de cada selected pulse a otra lista como "renglones"
        for j in range(len(lineas)):
            lineas_selp_evento.append(lineas[j])
    return(lineas_selp_evento)

# %% [markdown]
# ## Como ya he visto que trabajar con listas es muchísimo más rapido intentaré hacerlo sólo de esta manera (con listas), al final sí generaré un dataframe, pero sólo hasta el final.
#
# ## Primero debemos tomar el primer selected pulse como pivote y después debemos comparar contra todas las líneas que coincidan en linea detector y piso detector y seleccionarlas.

# %%
###################################
### OBTENIENDO LOS MEJORES HITS ###
###################################

###### CÓDIGO PARA RECORRER TODOS LOS ARCHIVOS ######

#### FILTRO PARA BUSCAR LOS HITS QUE HACEN MATCH CON EL SELECTED PULSE Y QUEDARNOS 
#### CON LA DATA DE MODULO OPTICO (ENTIENDASE RENGLON O RENGLONES QUE CORRESPONDEN AL SELECTED HIT)
#### EL CRITERIO ES QUEDARSE CON TODOS LOS RAW HITS QUE SEAN IGUALES EN X',Y',Z',X,Y, y Z.

inicio = 432   #En este caso como trabaje los archivos con otra PC, debo empezar en este índice.
best_hits = [] #Definimos la lista donde se guardarán los hits seleccionados

#Primer bucle donde se leerá la data de cada archivo
for z in range(1406):
    #Abrimos el archivo, de acuerdo con el índice z
    file = csv_path+csvarr[inicio]
    data = pd.read_csv(file, header=None)
    #Obteniendo los indices necesarios
    ind_startev,ind_runid,ind_weights,ind_muon,ind_bbfit,ind_bb_selp,ind_endev = indices(data)
    print("El archivo trabajando es:",file,"eventos:",len(ind_startev))
    #Obtenemos la metadata runID e interactionID ya que es la misma para cada archivo
    runID = int(list(str(data[0][ind_runid[0]]).split(" "))[0]) #Corregí esta línea era 0 en ambos
    interactionID = [lambda:1, lambda:2]["anumu" in str(file)]()
    print("Entrando al bucle para obtener los best-hits")
    bhcount_file = 0; rhcount_file = 0 #Contadores para "monitorear"
    ### Bucle para buscar los best hits de cada archivo en cada evento del archivo
    for j in range(len(ind_startev)):
        #Obtengo el frameID y trigger_counter, que son diferentes para cada evento
        temprunid = list(data[0][ind_runid[j]].split(" "))
        frameID = temprunid[1]; trigger_counter = temprunid [2]
        #Encontramos primero el # de lineas de rawhits y selected pulses
        difrawhits = ind_bb_selp[j] - ind_bbfit[j] #debe variar con la variable del bucle de eventos
        difselhits = ind_endev[j] - ind_bb_selp[j] #debe variar con la variable del bucle de eventos
        start_rawhit = ind_bbfit[j]+1; #debe variar con el bucle de eventos
        start_selhit = ind_bb_selp[j]+1 #debe variar con el bucle de eventos
        raw_hits = []; hits_raw_limpios = [];sel_hits = []; sel_hits_limpios = []
        #Obteniendo solo los raw_hits de un evento
        for i in range(difrawhits-1):
            temprawhit = list(data[0][start_rawhit+i].split(" "))
            raw_hits.append(temprawhit)
            #Limpiamos los raw hits obtenidos del evento
        for i in range(len(raw_hits)): hits_raw_limpios.append(limpiahit(raw_hits[i]))
        #Obteniendo solo los selected pulses (hits) del mismo evento
        for i in range(difselhits-1):
            tempselhit = list(data[0][start_selhit+i].split(" "))
            sel_hits.append(tempselhit)
        #Limpiamos los raw hits obtenidos del evento
        for i in range(len(sel_hits)): sel_hits_limpios.append(limpiahit(sel_hits[i]))
        #A continuación obtenemos todas las lineas que coinciden con cada selected pulse del evento
        templist = func_lineas_evento(sel_hits_limpios,hits_raw_limpios)
        #Agregamos la metadata que le falta a cada "row"
        for i in range(len(templist)):
            templist[i].insert(0,interactionID)
            templist[i].insert(0,trigger_counter)
            templist[i].insert(0,frameID)
            templist[i].insert(0,runID)
        for k in range(len(templist)):
            best_hits.append(templist[k])
        rhcount_file += len(raw_hits)
        bhcount_file += len(templist)
    print("Raw_hits:",rhcount_file,"Número de best_hits:",bhcount_file)
    inicio += 1 #Incremento para abrir el archivo correcto

print("\nFin de la extracción de la data")
# Out:
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_058730_numu_CC_a_reco.i3.csv eventos: 1396
# Entrando al bucle para obtener los best-hits
# Raw_hits: 408751 Número de best_hits: 39685
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_058770_anumu_CC_a_reco.i3.csv eventos: 597
# Entrando al bucle para obtener los best-hits
# Raw_hits: 287016 Número de best_hits: 26866
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_058770_numu_CC_a_reco.i3.csv eventos: 578
# Entrando al bucle para obtener los best-hits
# Raw_hits: 278775 Número de best_hits: 26565
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_058790_anumu_CC_a_reco.i3.csv eventos: 90
# Entrando al bucle para obtener los best-hits
# Raw_hits: 37691 Número de best_hits: 2295
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_058790_numu_CC_a_reco.i3.csv eventos: 665
# Entrando al bucle para obtener los best-hits
# Raw_hits: 298915 Número de best_hits: 27807
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_058810_anumu_CC_a_reco.i3.csv eventos: 1348
# Entrando al bucle para obtener los best-hits
# Raw_hits: 493890 Número de best_hits: 42434
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_058810_numu_CC_a_reco.i3.csv eventos: 1239
# Entrando al bucle para obtener los best-hits
# Raw_hits: 451379 Número de best_hits: 38631
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_058830_anumu_CC_a_reco.i3.csv eventos: 747
# Entrando al bucle para obtener los best-hits
# Raw_hits: 321065 Número de best_hits: 24864
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_058830_numu_CC_a_reco.i3.csv eventos: 686
# Entrando al bucle para obtener los best-hits
# Raw_hits: 294897 Número de best_hits: 24095
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_058890_anumu_CC_a_reco.i3.csv eventos: 1476
# Entrando al bucle para obtener los best-hits
# Raw_hits: 448551 Número de best_hits: 43161
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_058890_numu_CC_a_reco.i3.csv eventos: 1383
# Entrando al bucle para obtener los best-hits
# Raw_hits: 420683 Número de best_hits: 43222
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059020_anumu_CC_a_reco.i3.csv eventos: 1122
# Entrando al bucle para obtener los best-hits
# Raw_hits: 454016 Número de best_hits: 36548
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059020_numu_CC_a_reco.i3.csv eventos: 977
# Entrando al bucle para obtener los best-hits
# Raw_hits: 395538 Número de best_hits: 32857
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059040_anumu_CC_a_reco.i3.csv eventos: 1004
# Entrando al bucle para obtener los best-hits
# Raw_hits: 415506 Número de best_hits: 31938
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059040_numu_CC_a_reco.i3.csv eventos: 976
# Entrando al bucle para obtener los best-hits
# Raw_hits: 403624 Número de best_hits: 32252
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059080_anumu_CC_a_reco.i3.csv eventos: 1116
# Entrando al bucle para obtener los best-hits
# Raw_hits: 452341 Número de best_hits: 35417
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059080_numu_CC_a_reco.i3.csv eventos: 1026
# Entrando al bucle para obtener los best-hits
# Raw_hits: 412802 Número de best_hits: 33714
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059090_anumu_CC_a_reco.i3.csv eventos: 1028
# Entrando al bucle para obtener los best-hits
# Raw_hits: 451097 Número de best_hits: 33523
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059090_numu_CC_a_reco.i3.csv eventos: 931
# Entrando al bucle para obtener los best-hits
# Raw_hits: 414573 Número de best_hits: 32957
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059110_anumu_CC_a_reco.i3.csv eventos: 977
# Entrando al bucle para obtener los best-hits
# Raw_hits: 424011 Número de best_hits: 33016
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059110_numu_CC_a_reco.i3.csv eventos: 937
# Entrando al bucle para obtener los best-hits
# Raw_hits: 409992 Número de best_hits: 33392
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059150_anumu_CC_a_reco.i3.csv eventos: 927
# Entrando al bucle para obtener los best-hits
# Raw_hits: 421775 Número de best_hits: 30162
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059150_numu_CC_a_reco.i3.csv eventos: 901
# Entrando al bucle para obtener los best-hits
# Raw_hits: 406630 Número de best_hits: 29890
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059260_numu_CC_a_reco.i3.csv eventos: 967
# Entrando al bucle para obtener los best-hits
# Raw_hits: 399477 Número de best_hits: 31916
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059320_numu_CC_a_reco.i3.csv eventos: 853
# Entrando al bucle para obtener los best-hits
# Raw_hits: 387222 Número de best_hits: 30701
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059330_anumu_CC_a_reco.i3.csv eventos: 1000
# Entrando al bucle para obtener los best-hits
# Raw_hits: 415336 Número de best_hits: 31498
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059330_numu_CC_a_reco.i3.csv eventos: 908
# Entrando al bucle para obtener los best-hits
# Raw_hits: 378503 Número de best_hits: 29124
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059370_numu_CC_a_reco.i3.csv eventos: 1097
# Entrando al bucle para obtener los best-hits
# Raw_hits: 387220 Número de best_hits: 33579
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059380_anumu_CC_a_reco.i3.csv eventos: 1277
# Entrando al bucle para obtener los best-hits
# Raw_hits: 431307 Número de best_hits: 38161
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059380_numu_CC_a_reco.i3.csv eventos: 1067
# Entrando al bucle para obtener los best-hits
# Raw_hits: 359554 Número de best_hits: 32915
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059390_anumu_CC_a_reco.i3.csv eventos: 1211
# Entrando al bucle para obtener los best-hits
# Raw_hits: 411104 Número de best_hits: 36141
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059390_numu_CC_a_reco.i3.csv eventos: 1139
# Entrando al bucle para obtener los best-hits
# Raw_hits: 386501 Número de best_hits: 35035
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059430_anumu_CC_a_reco.i3.csv eventos: 1462
# Entrando al bucle para obtener los best-hits
# Raw_hits: 481040 Número de best_hits: 42244
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059450_anumu_CC_a_reco.i3.csv eventos: 1569
# Entrando al bucle para obtener los best-hits
# Raw_hits: 459860 Número de best_hits: 42853
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059580_anumu_CC_a_reco.i3.csv eventos: 1353
# Entrando al bucle para obtener los best-hits
# Raw_hits: 382005 Número de best_hits: 39214
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059580_numu_CC_a_reco.i3.csv eventos: 1269
# Entrando al bucle para obtener los best-hits
# Raw_hits: 356474 Número de best_hits: 36129
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059590_anumu_CC_a_reco.i3.csv eventos: 994
# Entrando al bucle para obtener los best-hits
# Raw_hits: 388042 Número de best_hits: 32182
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059600_anumu_CC_a_reco.i3.csv eventos: 1120
# Entrando al bucle para obtener los best-hits
# Raw_hits: 414511 Número de best_hits: 34727
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059600_numu_CC_a_reco.i3.csv eventos: 1068
# Entrando al bucle para obtener los best-hits
# Raw_hits: 400307 Número de best_hits: 36202
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059620_numu_CC_a_reco.i3.csv eventos: 1240
# Entrando al bucle para obtener los best-hits
# Raw_hits: 404164 Número de best_hits: 38941
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059640_anumu_CC_a_reco.i3.csv eventos: 1254
# Entrando al bucle para obtener los best-hits
# Raw_hits: 382112 Número de best_hits: 36859
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059640_numu_CC_a_reco.i3.csv eventos: 1250
# Entrando al bucle para obtener los best-hits
# Raw_hits: 382922 Número de best_hits: 37330
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059660_anumu_CC_a_reco.i3.csv eventos: 1515
# Entrando al bucle para obtener los best-hits
# Raw_hits: 428452 Número de best_hits: 42228
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059660_numu_CC_a_reco.i3.csv eventos: 1379
# Entrando al bucle para obtener los best-hits
# Raw_hits: 389819 Número de best_hits: 39200
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059670_anumu_CC_a_reco.i3.csv eventos: 1396
# Entrando al bucle para obtener los best-hits
# Raw_hits: 386691 Número de best_hits: 39620
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059670_numu_CC_a_reco.i3.csv eventos: 1258
# Entrando al bucle para obtener los best-hits
# Raw_hits: 347720 Número de best_hits: 37010
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059860_numu_CC_a_reco.i3.csv eventos: 1249
# Entrando al bucle para obtener los best-hits
# Raw_hits: 358131 Número de best_hits: 37536
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059870_anumu_CC_a_reco.i3.csv eventos: 1296
# Entrando al bucle para obtener los best-hits
# Raw_hits: 371607 Número de best_hits: 35612
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059870_numu_CC_a_reco.i3.csv eventos: 1199
# Entrando al bucle para obtener los best-hits
# Raw_hits: 344214 Número de best_hits: 34336
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059880_anumu_CC_a_reco.i3.csv eventos: 1389
# Entrando al bucle para obtener los best-hits
# Raw_hits: 436311 Número de best_hits: 38283
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059880_numu_CC_a_reco.i3.csv eventos: 1336
# Entrando al bucle para obtener los best-hits
# Raw_hits: 419884 Número de best_hits: 38524
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059890_numu_CC_a_reco.i3.csv eventos: 1213
# Entrando al bucle para obtener los best-hits
# Raw_hits: 396229 Número de best_hits: 37311
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059900_anumu_CC_a_reco.i3.csv eventos: 7
# Entrando al bucle para obtener los best-hits
# Raw_hits: 2144 Número de best_hits: 116
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059900_numu_CC_a_reco.i3.csv eventos: 1235
# Entrando al bucle para obtener los best-hits
# Raw_hits: 426782 Número de best_hits: 37405
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059910_anumu_CC_a_reco.i3.csv eventos: 1311
# Entrando al bucle para obtener los best-hits
# Raw_hits: 417380 Número de best_hits: 37730
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059910_numu_CC_a_reco.i3.csv eventos: 1224
# Entrando al bucle para obtener los best-hits
# Raw_hits: 391086 Número de best_hits: 36134
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059930_numu_CC_a_reco.i3.csv eventos: 1298
# Entrando al bucle para obtener los best-hits
# Raw_hits: 415958 Número de best_hits: 39457
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_059960_anumu_CC_a_reco.i3.csv eventos: 1361
# Entrando al bucle para obtener los best-hits
# Raw_hits: 419804 Número de best_hits: 37367
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060070_anumu_CC_a_reco.i3.csv eventos: 1658
# Entrando al bucle para obtener los best-hits
# Raw_hits: 487296 Número de best_hits: 43534
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060070_numu_CC_a_reco.i3.csv eventos: 1541
# Entrando al bucle para obtener los best-hits
# Raw_hits: 455872 Número de best_hits: 42106
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060100_anumu_CC_a_reco.i3.csv eventos: 1776
# Entrando al bucle para obtener los best-hits
# Raw_hits: 525280 Número de best_hits: 44551
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060100_numu_CC_a_reco.i3.csv eventos: 1535
# Entrando al bucle para obtener los best-hits
# Raw_hits: 456953 Número de best_hits: 40037
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060110_anumu_CC_a_reco.i3.csv eventos: 1371
# Entrando al bucle para obtener los best-hits
# Raw_hits: 374968 Número de best_hits: 37127
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060110_numu_CC_a_reco.i3.csv eventos: 1323
# Entrando al bucle para obtener los best-hits
# Raw_hits: 360706 Número de best_hits: 36947
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060120_anumu_CC_a_reco.i3.csv eventos: 1378
# Entrando al bucle para obtener los best-hits
# Raw_hits: 354157 Número de best_hits: 37514
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060120_numu_CC_a_reco.i3.csv eventos: 1315
# Entrando al bucle para obtener los best-hits
# Raw_hits: 337914 Número de best_hits: 34945
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060130_anumu_CC_a_reco.i3.csv eventos: 1631
# Entrando al bucle para obtener los best-hits
# Raw_hits: 469855 Número de best_hits: 42037
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060130_numu_CC_a_reco.i3.csv eventos: 1500
# Entrando al bucle para obtener los best-hits
# Raw_hits: 432350 Número de best_hits: 39642
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060150_anumu_CC_a_reco.i3.csv eventos: 1691
# Entrando al bucle para obtener los best-hits
# Raw_hits: 496693 Número de best_hits: 43673
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060310_numu_CC_a_reco.i3.csv eventos: 1669
# Entrando al bucle para obtener los best-hits
# Raw_hits: 453450 Número de best_hits: 42543
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060320_anumu_CC_a_reco.i3.csv eventos: 1652
# Entrando al bucle para obtener los best-hits
# Raw_hits: 447907 Número de best_hits: 41720
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060320_numu_CC_a_reco.i3.csv eventos: 1562
# Entrando al bucle para obtener los best-hits
# Raw_hits: 427543 Número de best_hits: 41075
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060380_anumu_CC_a_reco.i3.csv eventos: 1682
# Entrando al bucle para obtener los best-hits
# Raw_hits: 473003 Número de best_hits: 41821
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060380_numu_CC_a_reco.i3.csv eventos: 1571
# Entrando al bucle para obtener los best-hits
# Raw_hits: 444932 Número de best_hits: 41136
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060390_anumu_CC_a_reco.i3.csv eventos: 1730
# Entrando al bucle para obtener los best-hits
# Raw_hits: 474087 Número de best_hits: 42598
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060390_numu_CC_a_reco.i3.csv eventos: 1574
# Entrando al bucle para obtener los best-hits
# Raw_hits: 431216 Número de best_hits: 39739
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060410_anumu_CC_a_reco.i3.csv eventos: 1720
# Entrando al bucle para obtener los best-hits
# Raw_hits: 472714 Número de best_hits: 43664
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060420_anumu_CC_a_reco.i3.csv eventos: 1793
# Entrando al bucle para obtener los best-hits
# Raw_hits: 485729 Número de best_hits: 45004
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060440_numu_CC_a_reco.i3.csv eventos: 1526
# Entrando al bucle para obtener los best-hits
# Raw_hits: 418310 Número de best_hits: 40079
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060600_anumu_CC_a_reco.i3.csv eventos: 1625
# Entrando al bucle para obtener los best-hits
# Raw_hits: 547263 Número de best_hits: 43772
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060600_numu_CC_a_reco.i3.csv eventos: 1376
# Entrando al bucle para obtener los best-hits
# Raw_hits: 467523 Número de best_hits: 38592
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060610_anumu_CC_a_reco.i3.csv eventos: 1415
# Entrando al bucle para obtener los best-hits
# Raw_hits: 395452 Número de best_hits: 38383
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060610_numu_CC_a_reco.i3.csv eventos: 1238
# Entrando al bucle para obtener los best-hits
# Raw_hits: 349896 Número de best_hits: 36064
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060690_anumu_CC_a_reco.i3.csv eventos: 1689
# Entrando al bucle para obtener los best-hits
# Raw_hits: 463837 Número de best_hits: 42986
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060690_numu_CC_a_reco.i3.csv eventos: 1595
# Entrando al bucle para obtener los best-hits
# Raw_hits: 437094 Número de best_hits: 40315
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060720_anumu_CC_a_reco.i3.csv eventos: 1621
# Entrando al bucle para obtener los best-hits
# Raw_hits: 470163 Número de best_hits: 41031
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060720_numu_CC_a_reco.i3.csv eventos: 1583
# Entrando al bucle para obtener los best-hits
# Raw_hits: 460588 Número de best_hits: 40346
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060730_anumu_CC_a_reco.i3.csv eventos: 1728
# Entrando al bucle para obtener los best-hits
# Raw_hits: 487035 Número de best_hits: 44214
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060740_anumu_CC_a_reco.i3.csv eventos: 1636
# Entrando al bucle para obtener los best-hits
# Raw_hits: 441689 Número de best_hits: 39795
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060880_numu_CC_a_reco.i3.csv eventos: 1478
# Entrando al bucle para obtener los best-hits
# Raw_hits: 419707 Número de best_hits: 38661
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060910_anumu_CC_a_reco.i3.csv eventos: 1604
# Entrando al bucle para obtener los best-hits
# Raw_hits: 486698 Número de best_hits: 41150
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060910_numu_CC_a_reco.i3.csv eventos: 1462
# Entrando al bucle para obtener los best-hits
# Raw_hits: 446713 Número de best_hits: 39819
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060930_anumu_CC_a_reco.i3.csv eventos: 1360
# Entrando al bucle para obtener los best-hits
# Raw_hits: 385379 Número de best_hits: 36721
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060930_numu_CC_a_reco.i3.csv eventos: 1243
# Entrando al bucle para obtener los best-hits
# Raw_hits: 353860 Número de best_hits: 33954
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060940_anumu_CC_a_reco.i3.csv eventos: 1643
# Entrando al bucle para obtener los best-hits
# Raw_hits: 475062 Número de best_hits: 42675
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060940_numu_CC_a_reco.i3.csv eventos: 1490
# Entrando al bucle para obtener los best-hits
# Raw_hits: 428839 Número de best_hits: 37734
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060970_anumu_CC_a_reco.i3.csv eventos: 1690
# Entrando al bucle para obtener los best-hits
# Raw_hits: 443335 Número de best_hits: 41540
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060970_numu_CC_a_reco.i3.csv eventos: 1550
# Entrando al bucle para obtener los best-hits
# Raw_hits: 405964 Número de best_hits: 38241
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060990_anumu_CC_a_reco.i3.csv eventos: 1699
# Entrando al bucle para obtener los best-hits
# Raw_hits: 451903 Número de best_hits: 40518
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_060990_numu_CC_a_reco.i3.csv eventos: 1622
# Entrando al bucle para obtener los best-hits
# Raw_hits: 433970 Número de best_hits: 40143
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061010_anumu_CC_a_reco.i3.csv eventos: 1749
# Entrando al bucle para obtener los best-hits
# Raw_hits: 451526 Número de best_hits: 43440
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061010_numu_CC_a_reco.i3.csv eventos: 1561
# Entrando al bucle para obtener los best-hits
# Raw_hits: 402883 Número de best_hits: 38460
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061020_anumu_CC_a_reco.i3.csv eventos: 1706
# Entrando al bucle para obtener los best-hits
# Raw_hits: 446259 Número de best_hits: 41577
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061020_numu_CC_a_reco.i3.csv eventos: 1618
# Entrando al bucle para obtener los best-hits
# Raw_hits: 426725 Número de best_hits: 41250
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061030_anumu_CC_a_reco.i3.csv eventos: 1634
# Entrando al bucle para obtener los best-hits
# Raw_hits: 436805 Número de best_hits: 40699
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061030_numu_CC_a_reco.i3.csv eventos: 1553
# Entrando al bucle para obtener los best-hits
# Raw_hits: 416705 Número de best_hits: 38591
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061040_anumu_CC_a_reco.i3.csv eventos: 1640
# Entrando al bucle para obtener los best-hits
# Raw_hits: 449445 Número de best_hits: 40177
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061040_numu_CC_a_reco.i3.csv eventos: 1529
# Entrando al bucle para obtener los best-hits
# Raw_hits: 422134 Número de best_hits: 38133
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061050_anumu_CC_a_reco.i3.csv eventos: 1678
# Entrando al bucle para obtener los best-hits
# Raw_hits: 449353 Número de best_hits: 42544
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061050_numu_CC_a_reco.i3.csv eventos: 1507
# Entrando al bucle para obtener los best-hits
# Raw_hits: 403930 Número de best_hits: 38187
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061060_anumu_CC_a_reco.i3.csv eventos: 1707
# Entrando al bucle para obtener los best-hits
# Raw_hits: 457681 Número de best_hits: 42811
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061060_numu_CC_a_reco.i3.csv eventos: 1535
# Entrando al bucle para obtener los best-hits
# Raw_hits: 411463 Número de best_hits: 37435
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061070_anumu_CC_a_reco.i3.csv eventos: 1692
# Entrando al bucle para obtener los best-hits
# Raw_hits: 476770 Número de best_hits: 44002
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061070_numu_CC_a_reco.i3.csv eventos: 1522
# Entrando al bucle para obtener los best-hits
# Raw_hits: 428669 Número de best_hits: 37796
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061080_anumu_CC_a_reco.i3.csv eventos: 1593
# Entrando al bucle para obtener los best-hits
# Raw_hits: 440688 Número de best_hits: 40458
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061080_numu_CC_a_reco.i3.csv eventos: 1516
# Entrando al bucle para obtener los best-hits
# Raw_hits: 419891 Número de best_hits: 38870
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061090_anumu_CC_a_reco.i3.csv eventos: 1606
# Entrando al bucle para obtener los best-hits
# Raw_hits: 426493 Número de best_hits: 39114
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061090_numu_CC_a_reco.i3.csv eventos: 1539
# Entrando al bucle para obtener los best-hits
# Raw_hits: 411210 Número de best_hits: 38936
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061100_anumu_CC_a_reco.i3.csv eventos: 1635
# Entrando al bucle para obtener los best-hits
# Raw_hits: 434933 Número de best_hits: 39938
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061100_numu_CC_a_reco.i3.csv eventos: 1556
# Entrando al bucle para obtener los best-hits
# Raw_hits: 416128 Número de best_hits: 39661
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061140_anumu_CC_a_reco.i3.csv eventos: 1635
# Entrando al bucle para obtener los best-hits
# Raw_hits: 449121 Número de best_hits: 39817
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061140_numu_CC_a_reco.i3.csv eventos: 1534
# Entrando al bucle para obtener los best-hits
# Raw_hits: 426929 Número de best_hits: 40128
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061150_anumu_CC_a_reco.i3.csv eventos: 1671
# Entrando al bucle para obtener los best-hits
# Raw_hits: 457751 Número de best_hits: 42580
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061150_numu_CC_a_reco.i3.csv eventos: 1511
# Entrando al bucle para obtener los best-hits
# Raw_hits: 416481 Número de best_hits: 39475
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061160_anumu_CC_a_reco.i3.csv eventos: 1338
# Entrando al bucle para obtener los best-hits
# Raw_hits: 356294 Número de best_hits: 36485
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061160_numu_CC_a_reco.i3.csv eventos: 1244
# Entrando al bucle para obtener los best-hits
# Raw_hits: 328059 Número de best_hits: 33706
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061180_anumu_CC_a_reco.i3.csv eventos: 1195
# Entrando al bucle para obtener los best-hits
# Raw_hits: 352641 Número de best_hits: 32238
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061180_numu_CC_a_reco.i3.csv eventos: 1067
# Entrando al bucle para obtener los best-hits
# Raw_hits: 316983 Número de best_hits: 30930
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061210_anumu_CC_a_reco.i3.csv eventos: 1418
# Entrando al bucle para obtener los best-hits
# Raw_hits: 348575 Número de best_hits: 35764
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061390_numu_CC_a_reco.i3.csv eventos: 1550
# Entrando al bucle para obtener los best-hits
# Raw_hits: 451951 Número de best_hits: 41508
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061410_anumu_CC_a_reco.i3.csv eventos: 1593
# Entrando al bucle para obtener los best-hits
# Raw_hits: 407181 Número de best_hits: 37842
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061410_numu_CC_a_reco.i3.csv eventos: 1508
# Entrando al bucle para obtener los best-hits
# Raw_hits: 389332 Número de best_hits: 37825
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061440_anumu_CC_a_reco.i3.csv eventos: 1573
# Entrando al bucle para obtener los best-hits
# Raw_hits: 417738 Número de best_hits: 38836
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061440_numu_CC_a_reco.i3.csv eventos: 1497
# Entrando al bucle para obtener los best-hits
# Raw_hits: 399650 Número de best_hits: 38434
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061450_anumu_CC_a_reco.i3.csv eventos: 1603
# Entrando al bucle para obtener los best-hits
# Raw_hits: 399860 Número de best_hits: 37643
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061450_numu_CC_a_reco.i3.csv eventos: 1536
# Entrando al bucle para obtener los best-hits
# Raw_hits: 386271 Número de best_hits: 37582
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061460_anumu_CC_a_reco.i3.csv eventos: 1611
# Entrando al bucle para obtener los best-hits
# Raw_hits: 408336 Número de best_hits: 39784
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061460_numu_CC_a_reco.i3.csv eventos: 1489
# Entrando al bucle para obtener los best-hits
# Raw_hits: 381998 Número de best_hits: 39364
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061470_anumu_CC_a_reco.i3.csv eventos: 1594
# Entrando al bucle para obtener los best-hits
# Raw_hits: 418536 Número de best_hits: 39931
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061470_numu_CC_a_reco.i3.csv eventos: 1475
# Entrando al bucle para obtener los best-hits
# Raw_hits: 389404 Número de best_hits: 38106
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061480_anumu_CC_a_reco.i3.csv eventos: 1603
# Entrando al bucle para obtener los best-hits
# Raw_hits: 401059 Número de best_hits: 38912
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061480_numu_CC_a_reco.i3.csv eventos: 1490
# Entrando al bucle para obtener los best-hits
# Raw_hits: 373773 Número de best_hits: 37212
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061730_anumu_CC_a_reco.i3.csv eventos: 1237
# Entrando al bucle para obtener los best-hits
# Raw_hits: 381898 Número de best_hits: 37886
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061730_numu_CC_a_reco.i3.csv eventos: 1138
# Entrando al bucle para obtener los best-hits
# Raw_hits: 349738 Número de best_hits: 34156
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061740_anumu_CC_a_reco.i3.csv eventos: 1129
# Entrando al bucle para obtener los best-hits
# Raw_hits: 384592 Número de best_hits: 33831
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061740_numu_CC_a_reco.i3.csv eventos: 1059
# Entrando al bucle para obtener los best-hits
# Raw_hits: 358418 Número de best_hits: 31576
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061750_anumu_CC_a_reco.i3.csv eventos: 1321
# Entrando al bucle para obtener los best-hits
# Raw_hits: 373863 Número de best_hits: 37855
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061750_numu_CC_a_reco.i3.csv eventos: 1224
# Entrando al bucle para obtener los best-hits
# Raw_hits: 346450 Número de best_hits: 36371
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061760_anumu_CC_a_reco.i3.csv eventos: 1283
# Entrando al bucle para obtener los best-hits
# Raw_hits: 360605 Número de best_hits: 35027
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061760_numu_CC_a_reco.i3.csv eventos: 1182
# Entrando al bucle para obtener los best-hits
# Raw_hits: 334114 Número de best_hits: 34601
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061770_anumu_CC_a_reco.i3.csv eventos: 1326
# Entrando al bucle para obtener los best-hits
# Raw_hits: 376051 Número de best_hits: 36930
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061770_numu_CC_a_reco.i3.csv eventos: 1137
# Entrando al bucle para obtener los best-hits
# Raw_hits: 323667 Número de best_hits: 33146
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061800_anumu_CC_a_reco.i3.csv eventos: 1809
# Entrando al bucle para obtener los best-hits
# Raw_hits: 490911 Número de best_hits: 46069
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061800_numu_CC_a_reco.i3.csv eventos: 1709
# Entrando al bucle para obtener los best-hits
# Raw_hits: 468142 Número de best_hits: 46731
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061830_anumu_CC_a_reco.i3.csv eventos: 1781
# Entrando al bucle para obtener los best-hits
# Raw_hits: 483051 Número de best_hits: 44239
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061930_numu_CC_a_reco.i3.csv eventos: 1557
# Entrando al bucle para obtener los best-hits
# Raw_hits: 416618 Número de best_hits: 39085
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061960_numu_CC_a_reco.i3.csv eventos: 1736
# Entrando al bucle para obtener los best-hits
# Raw_hits: 433779 Número de best_hits: 44176
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061980_anumu_CC_a_reco.i3.csv eventos: 1764
# Entrando al bucle para obtener los best-hits
# Raw_hits: 479629 Número de best_hits: 44219
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061980_numu_CC_a_reco.i3.csv eventos: 1555
# Entrando al bucle para obtener los best-hits
# Raw_hits: 427244 Número de best_hits: 40549
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061990_anumu_CC_a_reco.i3.csv eventos: 1723
# Entrando al bucle para obtener los best-hits
# Raw_hits: 494007 Número de best_hits: 43683
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_061990_numu_CC_a_reco.i3.csv eventos: 1578
# Entrando al bucle para obtener los best-hits
# Raw_hits: 461392 Número de best_hits: 44269
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062030_anumu_CC_a_reco.i3.csv eventos: 1637
# Entrando al bucle para obtener los best-hits
# Raw_hits: 462590 Número de best_hits: 42996
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062050_anumu_CC_a_reco.i3.csv eventos: 1820
# Entrando al bucle para obtener los best-hits
# Raw_hits: 458149 Número de best_hits: 43812
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062050_numu_CC_a_reco.i3.csv eventos: 1651
# Entrando al bucle para obtener los best-hits
# Raw_hits: 420997 Número de best_hits: 42909
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062080_anumu_CC_a_reco.i3.csv eventos: 1712
# Entrando al bucle para obtener los best-hits
# Raw_hits: 480152 Número de best_hits: 44257
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062080_numu_CC_a_reco.i3.csv eventos: 1672
# Entrando al bucle para obtener los best-hits
# Raw_hits: 471913 Número de best_hits: 46282
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062100_anumu_CC_a_reco.i3.csv eventos: 1718
# Entrando al bucle para obtener los best-hits
# Raw_hits: 460825 Número de best_hits: 40924
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062180_anumu_CC_a_reco.i3.csv eventos: 1497
# Entrando al bucle para obtener los best-hits
# Raw_hits: 359045 Número de best_hits: 39330
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062180_numu_CC_a_reco.i3.csv eventos: 1336
# Entrando al bucle para obtener los best-hits
# Raw_hits: 319002 Número de best_hits: 34824
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062230_anumu_CC_a_reco.i3.csv eventos: 1618
# Entrando al bucle para obtener los best-hits
# Raw_hits: 466127 Número de best_hits: 41519
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062230_numu_CC_a_reco.i3.csv eventos: 1513
# Entrando al bucle para obtener los best-hits
# Raw_hits: 436178 Número de best_hits: 38535
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062240_anumu_CC_a_reco.i3.csv eventos: 1708
# Entrando al bucle para obtener los best-hits
# Raw_hits: 447091 Número de best_hits: 42645
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062240_numu_CC_a_reco.i3.csv eventos: 1596
# Entrando al bucle para obtener los best-hits
# Raw_hits: 417723 Número de best_hits: 40433
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062250_anumu_CC_a_reco.i3.csv eventos: 1726
# Entrando al bucle para obtener los best-hits
# Raw_hits: 464770 Número de best_hits: 42109
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062260_anumu_CC_a_reco.i3.csv eventos: 1753
# Entrando al bucle para obtener los best-hits
# Raw_hits: 481777 Número de best_hits: 45410
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062270_anumu_CC_a_reco.i3.csv eventos: 1638
# Entrando al bucle para obtener los best-hits
# Raw_hits: 466891 Número de best_hits: 42880
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062290_anumu_CC_a_reco.i3.csv eventos: 1697
# Entrando al bucle para obtener los best-hits
# Raw_hits: 456318 Número de best_hits: 42209
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062290_numu_CC_a_reco.i3.csv eventos: 1537
# Entrando al bucle para obtener los best-hits
# Raw_hits: 415522 Número de best_hits: 40442
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062390_numu_CC_a_reco.i3.csv eventos: 1131
# Entrando al bucle para obtener los best-hits
# Raw_hits: 335623 Número de best_hits: 32523
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062400_anumu_CC_a_reco.i3.csv eventos: 1200
# Entrando al bucle para obtener los best-hits
# Raw_hits: 356066 Número de best_hits: 34997
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062400_numu_CC_a_reco.i3.csv eventos: 1149
# Entrando al bucle para obtener los best-hits
# Raw_hits: 337720 Número de best_hits: 32553
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062410_anumu_CC_a_reco.i3.csv eventos: 1029
# Entrando al bucle para obtener los best-hits
# Raw_hits: 333447 Número de best_hits: 29074
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062410_numu_CC_a_reco.i3.csv eventos: 1000
# Entrando al bucle para obtener los best-hits
# Raw_hits: 324250 Número de best_hits: 29625
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062420_anumu_CC_a_reco.i3.csv eventos: 1188
# Entrando al bucle para obtener los best-hits
# Raw_hits: 361672 Número de best_hits: 35378
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062420_numu_CC_a_reco.i3.csv eventos: 1107
# Entrando al bucle para obtener los best-hits
# Raw_hits: 337533 Número de best_hits: 33825
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062440_anumu_CC_a_reco.i3.csv eventos: 1046
# Entrando al bucle para obtener los best-hits
# Raw_hits: 357395 Número de best_hits: 30763
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062440_numu_CC_a_reco.i3.csv eventos: 931
# Entrando al bucle para obtener los best-hits
# Raw_hits: 322316 Número de best_hits: 29979
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062450_anumu_CC_a_reco.i3.csv eventos: 1287
# Entrando al bucle para obtener los best-hits
# Raw_hits: 366239 Número de best_hits: 37648
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062450_numu_CC_a_reco.i3.csv eventos: 1214
# Entrando al bucle para obtener los best-hits
# Raw_hits: 342656 Número de best_hits: 33616
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062460_anumu_CC_a_reco.i3.csv eventos: 1324
# Entrando al bucle para obtener los best-hits
# Raw_hits: 352898 Número de best_hits: 36790
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062460_numu_CC_a_reco.i3.csv eventos: 1247
# Entrando al bucle para obtener los best-hits
# Raw_hits: 332043 Número de best_hits: 35429
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062500_numu_CC_a_reco.i3.csv eventos: 1665
# Entrando al bucle para obtener los best-hits
# Raw_hits: 439473 Número de best_hits: 42958
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062560_anumu_CC_a_reco.i3.csv eventos: 1128
# Entrando al bucle para obtener los best-hits
# Raw_hits: 384523 Número de best_hits: 35416
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062730_anumu_CC_a_reco.i3.csv eventos: 1102
# Entrando al bucle para obtener los best-hits
# Raw_hits: 361733 Número de best_hits: 32123
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062730_numu_CC_a_reco.i3.csv eventos: 1077
# Entrando al bucle para obtener los best-hits
# Raw_hits: 355279 Número de best_hits: 33045
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062780_anumu_CC_a_reco.i3.csv eventos: 1246
# Entrando al bucle para obtener los best-hits
# Raw_hits: 333632 Número de best_hits: 34825
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062780_numu_CC_a_reco.i3.csv eventos: 1183
# Entrando al bucle para obtener los best-hits
# Raw_hits: 313929 Número de best_hits: 32376
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062800_anumu_CC_a_reco.i3.csv eventos: 1752
# Entrando al bucle para obtener los best-hits
# Raw_hits: 451527 Número de best_hits: 44336
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062800_numu_CC_a_reco.i3.csv eventos: 1675
# Entrando al bucle para obtener los best-hits
# Raw_hits: 432256 Número de best_hits: 43359
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062930_anumu_CC_a_reco.i3.csv eventos: 989
# Entrando al bucle para obtener los best-hits
# Raw_hits: 337210 Número de best_hits: 31467
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_062930_numu_CC_a_reco.i3.csv eventos: 942
# Entrando al bucle para obtener los best-hits
# Raw_hits: 318695 Número de best_hits: 29780
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_063030_numu_CC_a_reco.i3.csv eventos: 799
# Entrando al bucle para obtener los best-hits
# Raw_hits: 282960 Número de best_hits: 24312
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_063060_anumu_CC_a_reco.i3.csv eventos: 952
# Entrando al bucle para obtener los best-hits
# Raw_hits: 315479 Número de best_hits: 27370
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_063060_numu_CC_a_reco.i3.csv eventos: 916
# Entrando al bucle para obtener los best-hits
# Raw_hits: 303042 Número de best_hits: 27389
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_063070_numu_CC_a_reco.i3.csv eventos: 967
# Entrando al bucle para obtener los best-hits
# Raw_hits: 323826 Número de best_hits: 29292
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_063080_anumu_CC_a_reco.i3.csv eventos: 959
# Entrando al bucle para obtener los best-hits
# Raw_hits: 333271 Número de best_hits: 28348
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_063230_numu_CC_a_reco.i3.csv eventos: 563
# Entrando al bucle para obtener los best-hits
# Raw_hits: 198612 Número de best_hits: 19278
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_063330_anumu_CC_a_reco.i3.csv eventos: 1305
# Entrando al bucle para obtener los best-hits
# Raw_hits: 306010 Número de best_hits: 33563
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_063330_numu_CC_a_reco.i3.csv eventos: 1177
# Entrando al bucle para obtener los best-hits
# Raw_hits: 278222 Número de best_hits: 32593
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_063340_numu_CC_a_reco.i3.csv eventos: 1407
# Entrando al bucle para obtener los best-hits
# Raw_hits: 399361 Número de best_hits: 36629
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_063380_anumu_CC_a_reco.i3.csv eventos: 1591
# Entrando al bucle para obtener los best-hits
# Raw_hits: 398079 Número de best_hits: 37673
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_063380_numu_CC_a_reco.i3.csv eventos: 1548
# Entrando al bucle para obtener los best-hits
# Raw_hits: 389335 Número de best_hits: 38716
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_063390_anumu_CC_a_reco.i3.csv eventos: 1599
# Entrando al bucle para obtener los best-hits
# Raw_hits: 488943 Número de best_hits: 41093
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_063400_anumu_CC_a_reco.i3.csv eventos: 1226
# Entrando al bucle para obtener los best-hits
# Raw_hits: 441215 Número de best_hits: 38925
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_063400_numu_CC_a_reco.i3.csv eventos: 1207
# Entrando al bucle para obtener los best-hits
# Raw_hits: 433806 Número de best_hits: 38987
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_063550_anumu_CC_a_reco.i3.csv eventos: 1138
# Entrando al bucle para obtener los best-hits
# Raw_hits: 475223 Número de best_hits: 37044
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_063550_numu_CC_a_reco.i3.csv eventos: 967
# Entrando al bucle para obtener los best-hits
# Raw_hits: 403052 Número de best_hits: 31920
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064140_anumu_CC_a_reco.i3.csv eventos: 1212
# Entrando al bucle para obtener los best-hits
# Raw_hits: 383643 Número de best_hits: 37165
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064140_numu_CC_a_reco.i3.csv eventos: 1113
# Entrando al bucle para obtener los best-hits
# Raw_hits: 349465 Número de best_hits: 32084
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064150_anumu_CC_a_reco.i3.csv eventos: 1088
# Entrando al bucle para obtener los best-hits
# Raw_hits: 403048 Número de best_hits: 33818
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064200_anumu_CC_a_reco.i3.csv eventos: 371
# Entrando al bucle para obtener los best-hits
# Raw_hits: 159206 Número de best_hits: 14780
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064200_numu_CC_a_reco.i3.csv eventos: 337
# Entrando al bucle para obtener los best-hits
# Raw_hits: 142912 Número de best_hits: 12726
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064400_anumu_CC_a_reco.i3.csv eventos: 65
# Entrando al bucle para obtener los best-hits
# Raw_hits: 23433 Número de best_hits: 2336
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064400_numu_CC_a_reco.i3.csv eventos: 60
# Entrando al bucle para obtener los best-hits
# Raw_hits: 18259 Número de best_hits: 2221
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064430_numu_CC_a_reco.i3.csv eventos: 1033
# Entrando al bucle para obtener los best-hits
# Raw_hits: 347612 Número de best_hits: 32566
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064440_anumu_CC_a_reco.i3.csv eventos: 1074
# Entrando al bucle para obtener los best-hits
# Raw_hits: 479703 Número de best_hits: 35446
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064440_numu_CC_a_reco.i3.csv eventos: 1077
# Entrando al bucle para obtener los best-hits
# Raw_hits: 478798 Número de best_hits: 35877
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064450_anumu_CC_a_reco.i3.csv eventos: 961
# Entrando al bucle para obtener los best-hits
# Raw_hits: 345040 Número de best_hits: 29238
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064450_numu_CC_a_reco.i3.csv eventos: 911
# Entrando al bucle para obtener los best-hits
# Raw_hits: 324264 Número de best_hits: 27597
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064500_anumu_CC_a_reco.i3.csv eventos: 660
# Entrando al bucle para obtener los best-hits
# Raw_hits: 275893 Número de best_hits: 22720
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064500_numu_CC_a_reco.i3.csv eventos: 637
# Entrando al bucle para obtener los best-hits
# Raw_hits: 264205 Número de best_hits: 21375
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064600_numu_CC_a_reco.i3.csv eventos: 837
# Entrando al bucle para obtener los best-hits
# Raw_hits: 369321 Número de best_hits: 27461
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064630_anumu_CC_a_reco.i3.csv eventos: 308
# Entrando al bucle para obtener los best-hits
# Raw_hits: 161940 Número de best_hits: 12367
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064630_numu_CC_a_reco.i3.csv eventos: 245
# Entrando al bucle para obtener los best-hits
# Raw_hits: 124850 Número de best_hits: 8335
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064640_anumu_CC_a_reco.i3.csv eventos: 339
# Entrando al bucle para obtener los best-hits
# Raw_hits: 197565 Número de best_hits: 13930
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064640_numu_CC_a_reco.i3.csv eventos: 349
# Entrando al bucle para obtener los best-hits
# Raw_hits: 202949 Número de best_hits: 14409
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064680_anumu_CC_a_reco.i3.csv eventos: 26
# Entrando al bucle para obtener los best-hits
# Raw_hits: 12899 Número de best_hits: 814
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064680_numu_CC_a_reco.i3.csv eventos: 7
# Entrando al bucle para obtener los best-hits
# Raw_hits: 2297 Número de best_hits: 252
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064690_anumu_CC_a_reco.i3.csv eventos: 693
# Entrando al bucle para obtener los best-hits
# Raw_hits: 335824 Número de best_hits: 27737
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064690_numu_CC_a_reco.i3.csv eventos: 623
# Entrando al bucle para obtener los best-hits
# Raw_hits: 302699 Número de best_hits: 27961
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064750_anumu_CC_a_reco.i3.csv eventos: 1120
# Entrando al bucle para obtener los best-hits
# Raw_hits: 577179 Número de best_hits: 38779
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064750_numu_CC_a_reco.i3.csv eventos: 993
# Entrando al bucle para obtener los best-hits
# Raw_hits: 515957 Número de best_hits: 37130
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064760_anumu_CC_a_reco.i3.csv eventos: 1169
# Entrando al bucle para obtener los best-hits
# Raw_hits: 519862 Número de best_hits: 37768
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064760_numu_CC_a_reco.i3.csv eventos: 1068
# Entrando al bucle para obtener los best-hits
# Raw_hits: 478129 Número de best_hits: 35664
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064810_anumu_CC_a_reco.i3.csv eventos: 16
# Entrando al bucle para obtener los best-hits
# Raw_hits: 4345 Número de best_hits: 544
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064810_numu_CC_a_reco.i3.csv eventos: 23
# Entrando al bucle para obtener los best-hits
# Raw_hits: 7431 Número de best_hits: 786
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064890_anumu_CC_a_reco.i3.csv eventos: 1004
# Entrando al bucle para obtener los best-hits
# Raw_hits: 537137 Número de best_hits: 36290
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064890_numu_CC_a_reco.i3.csv eventos: 921
# Entrando al bucle para obtener los best-hits
# Raw_hits: 491675 Número de best_hits: 33283
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064900_numu_CC_a_reco.i3.csv eventos: 849
# Entrando al bucle para obtener los best-hits
# Raw_hits: 461298 Número de best_hits: 31087
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064910_anumu_CC_a_reco.i3.csv eventos: 864
# Entrando al bucle para obtener los best-hits
# Raw_hits: 457760 Número de best_hits: 30501
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064910_numu_CC_a_reco.i3.csv eventos: 842
# Entrando al bucle para obtener los best-hits
# Raw_hits: 449698 Número de best_hits: 32088
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064920_anumu_CC_a_reco.i3.csv eventos: 819
# Entrando al bucle para obtener los best-hits
# Raw_hits: 407439 Número de best_hits: 28486
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_064920_numu_CC_a_reco.i3.csv eventos: 788
# Entrando al bucle para obtener los best-hits
# Raw_hits: 393866 Número de best_hits: 27163
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065010_anumu_CC_a_reco.i3.csv eventos: 889
# Entrando al bucle para obtener los best-hits
# Raw_hits: 442728 Número de best_hits: 30380
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065030_anumu_CC_a_reco.i3.csv eventos: 733
# Entrando al bucle para obtener los best-hits
# Raw_hits: 375583 Número de best_hits: 25309
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065030_numu_CC_a_reco.i3.csv eventos: 654
# Entrando al bucle para obtener los best-hits
# Raw_hits: 335871 Número de best_hits: 24203
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065050_anumu_CC_a_reco.i3.csv eventos: 494
# Entrando al bucle para obtener los best-hits
# Raw_hits: 284844 Número de best_hits: 21606
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065050_numu_CC_a_reco.i3.csv eventos: 467
# Entrando al bucle para obtener los best-hits
# Raw_hits: 271002 Número de best_hits: 20932
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065100_anumu_CC_a_reco.i3.csv eventos: 89
# Entrando al bucle para obtener los best-hits
# Raw_hits: 36266 Número de best_hits: 3090
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065100_numu_CC_a_reco.i3.csv eventos: 83
# Entrando al bucle para obtener los best-hits
# Raw_hits: 36072 Número de best_hits: 2830
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065120_anumu_CC_a_reco.i3.csv eventos: 772
# Entrando al bucle para obtener los best-hits
# Raw_hits: 529296 Número de best_hits: 36133
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065120_numu_CC_a_reco.i3.csv eventos: 729
# Entrando al bucle para obtener los best-hits
# Raw_hits: 501450 Número de best_hits: 36006
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065140_anumu_CC_a_reco.i3.csv eventos: 792
# Entrando al bucle para obtener los best-hits
# Raw_hits: 556303 Número de best_hits: 38279
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065140_numu_CC_a_reco.i3.csv eventos: 731
# Entrando al bucle para obtener los best-hits
# Raw_hits: 509854 Número de best_hits: 35088
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065150_anumu_CC_a_reco.i3.csv eventos: 727
# Entrando al bucle para obtener los best-hits
# Raw_hits: 531825 Número de best_hits: 34720
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065150_numu_CC_a_reco.i3.csv eventos: 724
# Entrando al bucle para obtener los best-hits
# Raw_hits: 527327 Número de best_hits: 35691
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065160_anumu_CC_a_reco.i3.csv eventos: 753
# Entrando al bucle para obtener los best-hits
# Raw_hits: 570215 Número de best_hits: 39033
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065160_numu_CC_a_reco.i3.csv eventos: 699
# Entrando al bucle para obtener los best-hits
# Raw_hits: 529916 Número de best_hits: 34218
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065180_anumu_CC_a_reco.i3.csv eventos: 838
# Entrando al bucle para obtener los best-hits
# Raw_hits: 573248 Número de best_hits: 40054
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065180_numu_CC_a_reco.i3.csv eventos: 726
# Entrando al bucle para obtener los best-hits
# Raw_hits: 494791 Número de best_hits: 34940
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065350_numu_CC_a_reco.i3.csv eventos: 1070
# Entrando al bucle para obtener los best-hits
# Raw_hits: 658626 Número de best_hits: 43026
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065360_anumu_CC_a_reco.i3.csv eventos: 1089
# Entrando al bucle para obtener los best-hits
# Raw_hits: 664580 Número de best_hits: 43174
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065360_numu_CC_a_reco.i3.csv eventos: 1098
# Entrando al bucle para obtener los best-hits
# Raw_hits: 670437 Número de best_hits: 44043
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065390_anumu_CC_a_reco.i3.csv eventos: 1001
# Entrando al bucle para obtener los best-hits
# Raw_hits: 341524 Número de best_hits: 29399
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065390_numu_CC_a_reco.i3.csv eventos: 1027
# Entrando al bucle para obtener los best-hits
# Raw_hits: 352920 Número de best_hits: 32230
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065400_anumu_CC_a_reco.i3.csv eventos: 895
# Entrando al bucle para obtener los best-hits
# Raw_hits: 325168 Número de best_hits: 27598
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065400_numu_CC_a_reco.i3.csv eventos: 884
# Entrando al bucle para obtener los best-hits
# Raw_hits: 320085 Número de best_hits: 27498
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065410_anumu_CC_a_reco.i3.csv eventos: 726
# Entrando al bucle para obtener los best-hits
# Raw_hits: 293378 Número de best_hits: 22152
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065410_numu_CC_a_reco.i3.csv eventos: 773
# Entrando al bucle para obtener los best-hits
# Raw_hits: 314625 Número de best_hits: 25112
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065440_anumu_CC_a_reco.i3.csv eventos: 1015
# Entrando al bucle para obtener los best-hits
# Raw_hits: 394477 Número de best_hits: 31355
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065440_numu_CC_a_reco.i3.csv eventos: 960
# Entrando al bucle para obtener los best-hits
# Raw_hits: 372013 Número de best_hits: 30573
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065480_anumu_CC_a_reco.i3.csv eventos: 664
# Entrando al bucle para obtener los best-hits
# Raw_hits: 343566 Número de best_hits: 27594
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065480_numu_CC_a_reco.i3.csv eventos: 618
# Entrando al bucle para obtener los best-hits
# Raw_hits: 320339 Número de best_hits: 26892
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065500_anumu_CC_a_reco.i3.csv eventos: 1007
# Entrando al bucle para obtener los best-hits
# Raw_hits: 482228 Número de best_hits: 32953
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065500_numu_CC_a_reco.i3.csv eventos: 1029
# Entrando al bucle para obtener los best-hits
# Raw_hits: 500312 Número de best_hits: 37206
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065520_anumu_CC_a_reco.i3.csv eventos: 1047
# Entrando al bucle para obtener los best-hits
# Raw_hits: 529936 Número de best_hits: 37381
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065520_numu_CC_a_reco.i3.csv eventos: 923
# Entrando al bucle para obtener los best-hits
# Raw_hits: 465017 Número de best_hits: 32114
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065530_anumu_CC_a_reco.i3.csv eventos: 1042
# Entrando al bucle para obtener los best-hits
# Raw_hits: 570950 Número de best_hits: 37233
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065540_anumu_CC_a_reco.i3.csv eventos: 647
# Entrando al bucle para obtener los best-hits
# Raw_hits: 388573 Número de best_hits: 30968
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065540_numu_CC_a_reco.i3.csv eventos: 595
# Entrando al bucle para obtener los best-hits
# Raw_hits: 356198 Número de best_hits: 27280
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065590_anumu_CC_a_reco.i3.csv eventos: 1159
# Entrando al bucle para obtener los best-hits
# Raw_hits: 516114 Número de best_hits: 39891
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065590_numu_CC_a_reco.i3.csv eventos: 1125
# Entrando al bucle para obtener los best-hits
# Raw_hits: 500543 Número de best_hits: 37253
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065600_anumu_CC_a_reco.i3.csv eventos: 1157
# Entrando al bucle para obtener los best-hits
# Raw_hits: 523687 Número de best_hits: 38929
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065600_numu_CC_a_reco.i3.csv eventos: 1052
# Entrando al bucle para obtener los best-hits
# Raw_hits: 476878 Número de best_hits: 35026
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065610_anumu_CC_a_reco.i3.csv eventos: 1162
# Entrando al bucle para obtener los best-hits
# Raw_hits: 495772 Número de best_hits: 37368
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065610_numu_CC_a_reco.i3.csv eventos: 1109
# Entrando al bucle para obtener los best-hits
# Raw_hits: 471997 Número de best_hits: 36073
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065620_anumu_CC_a_reco.i3.csv eventos: 1136
# Entrando al bucle para obtener los best-hits
# Raw_hits: 487457 Número de best_hits: 36927
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065620_numu_CC_a_reco.i3.csv eventos: 1121
# Entrando al bucle para obtener los best-hits
# Raw_hits: 488115 Número de best_hits: 38724
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065630_anumu_CC_a_reco.i3.csv eventos: 1198
# Entrando al bucle para obtener los best-hits
# Raw_hits: 529478 Número de best_hits: 40378
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065640_anumu_CC_a_reco.i3.csv eventos: 1113
# Entrando al bucle para obtener los best-hits
# Raw_hits: 461891 Número de best_hits: 35710
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065640_numu_CC_a_reco.i3.csv eventos: 987
# Entrando al bucle para obtener los best-hits
# Raw_hits: 413842 Número de best_hits: 34425
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065660_anumu_CC_a_reco.i3.csv eventos: 1048
# Entrando al bucle para obtener los best-hits
# Raw_hits: 411445 Número de best_hits: 34263
# El archivo trabajando es: F:\DATA_TFM\CSVs\MC_065660_numu_CC_a_reco.i3.csv eventos: 952
# Entrando al bucle para obtener los best-hits

# %%
#Pasamos a dataframe la lista con todos los hits seleccionados, en este caso de un archivo
print(len(best_hits))
columnas = ['runID','frameID','trigger_counter','interactionID','hit','#hit','lin_det','piso_det','mód_opt',
            'X\'','Y\'','Z\'','X','Y','Z','tiempo','amp','frec_hits']
df = pd.DataFrame(best_hits,columns=columnas)

# %%
df.sample(5)

# %%
#Guardamos el dataframe como un archivo CSV para unirlo con el otro (Laptop casa) ya procesado
#Todavía falta generar la transformación azimut y zenit pero eso será cuando ya tenga el dataframe completo

#outputpath = "Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CLEANDATA\\"
outputpath = "F:\DATA_TFM\CLEANDATA\\"
    
df.to_csv(outputpath+"data_best_hits.csv", index = None)#, header=None)

# %% [markdown]
# ## A PARTIR DE AQUI FUE LO PRIMERO QUE REALIZE PARA LLEGAR AL ALGORITMO Y PROGRAMA DE LAS PRIMERAS CELDAS.

# %%
###################################
### OBTENIENDO LOS MEJORES HITS ###
###################################

## Por el momento será para un solo archivo, posteriormente haré el bucle.

#Leyendo el archivo csv ya sin las líneas no deseadas en un dataframe
file = csv_path+csvarr[0]
print("El archivo trabajando es: ",file)
data = pd.read_csv(file, header=None)

#Obteniendo los indices necesarios
ind_startev,ind_runid,ind_weights,ind_muon,ind_bbfit,ind_bb_selp,ind_endev = indices(data)

# %%
#Ya que tenemos dos funciones, 1 que nos da las lineas que coinciden con el selected puls por linea y piso
#y otra que nos da todas las lineas que coinciden con todos los selp de un evento
#hay que proceder a iterar para todos los eventos de un mismo archivo

best_hits = []

#Requerimos el runID, el cual es el mismo para todos los selected pulses de todos los eventos en un mismo archivo
runID = int(list(str(data[0][ind_runid[0]]).split(" "))[0])
#Igual como el interactionID es el mismo para todos, asigno 1 si el archivo es "numu" y 2 si es "anumu"
interactionID = [lambda:1, lambda:2]["anumu" in str(file)]()

#Requerimos tambien el frameID, este dato si cambia por cada evento
#Por ultimo necesitamos el trigger_counter, que cambia por cada evento

for j in range(len(ind_startev)):
    #Obtengo el frameID y trigger_counter, que son diferentes para cada evento
    temprunid = list(data[0][ind_runid[j]].split(" "))
    frameID = temprunid[1]; trigger_counter = temprunid [2]
    #Encontramos primero el # de lineas de rawhits y selected pulses
    difrawhits = ind_bb_selp[j] - ind_bbfit[j] #debe variar con la variable del bucle de eventos
    difselhits = ind_endev[j] - ind_bb_selp[j] #debe variar con la variable del bucle de eventos
    start_rawhit = ind_bbfit[j]+1; #debe variar con el bucle de eventos
    start_selhit = ind_bb_selp[j]+1 #debe variar con el bucle de eventos
    raw_hits = []; hits_raw_limpios = [];sel_hits = []; sel_hits_limpios = []
    #Obteniendo solo los raw_hits de un evento
    for i in range(difrawhits-1):
        temprawhit = list(data[0][start_rawhit+i].split(" "))
        raw_hits.append(temprawhit)
    #Limpiamos los raw hits obtenidos del evento
    for i in range(len(raw_hits)): hits_raw_limpios.append(limpiahit(raw_hits[i]))
    #Obteniendo solo los selected pulses (hits) del mismo evento
    for i in range(difselhits-1):
        tempselhit = list(data[0][start_selhit+i].split(" "))
        sel_hits.append(tempselhit)
    #Limpiamos los raw hits obtenidos del evento
    for i in range(len(sel_hits)): sel_hits_limpios.append(limpiahit(sel_hits[i]))
    #A continuación obtenemos todas las lineas que coinciden con cada selected pulse del evento
    templist = func_lineas_evento(sel_hits_limpios,hits_raw_limpios)
    #Agregamos la metadata que le falta a cada "row"
    for i in range(len(templist)):
        templist[i].insert(0,interactionID)
        templist[i].insert(0,trigger_counter)
        templist[i].insert(0,frameID)
        templist[i].insert(0,runID)
    for k in range(len(templist)):
        best_hits.append(templist[k])

# %%
#Pasamos a dataframe la lista con todos los hits seleccionados, en este caso de un archivo
print(len(best_hits))
columnas = ['runID','frameID','trigger_counter','interactionID','hit','#hit','lin_det','piso_det','mód_opt',
            'X\'','Y\'','Z\'','X','Y','Z','tiempo','amp','frec_hits']
df = pd.DataFrame(best_hits,columns=columnas)

# %%
tempdf = df.loc[df['runID'].isin(["25800"])]
tempdf.tail(5)

# %%
print("El tamaño del dataframe es:",df.shape)

tempdf = df.loc[df['runID'].isin(["25800"])]

#tempdf.loc[tempdf['mód_opt'].isin(["1"])]

# %%
df.sample(10)

# %%
#Función que hice para buscar un frameID en específico en el dataframe final
def func_frameID(num,df):
    tempdf = df.loc[df['frameID'].isin([str(num)])]
    #print(tempdf.head(5))
    return(tempdf)

# %%
otrodf = func_frameID(45225,df)

# %%
otrodf

# %%
#### FILTRO PARA BUSCAR LOS HITS QUE HACEN MATCH CON EL SELECTED PULSE Y QUEDARNOS 
#### CON LA DATA DE MODULO OPTICO (ENTIENDASE RENGLON O RENGLONES QUE CORRESPONDEN AL SELECTED HIT)
#### EL CRITERIO ES QUEDARSE CON TODOS LOS RAW HITS QUE SEAN IGUALES EN X',Y',Z',X,Y, y Z.

#Abro el archivo a trabajar y paso el contenido a un dataframe
file = csv_path+csvarr[0]
print("El archivo trabajando es: ",file)
data = pd.read_csv(file, header=None)

#Obteniendo los indices necesarios
#ind_startev,ind_runid,ind_weights,ind_muon,ind_bbfit,ind_bb_selp,ind_endev = indices(data)

#Variables auxiliares
columnas = ['hit','#hit','lin_det','piso_det','mód_opt',
            'X\'','Y\'','Z\'','X','Y','Z','tiempo','amp','frec_hits']
df_hits = pd.DataFrame(columns=columnas)
#Obtengo el runID que es el mismo para cada archivo
runID = int(list(str(data[0][ind_runid[0]]).split(" "))[0])
#Obtengo el frameID que es diferente para cada evento
temprunid = list(data[0][ind_runid[1]].split(" ")) #Esto va en el bucle para recorrer todos los archivos
frameID = temprunid[1]; trigger_counter = temprunid [2]
print("runID:",runID,"frameID:",frameID)

#Este bucle recorre cada row de los selected pulses
for j in range(sel_hits_ev_df.shape[0]):
    selp = sel_hits_ev_df.iloc[j][5:11]
    #Este bucle recorre cada row de los raw hits seleccionados.
    lindet_search = sel_hits_ev_df.iloc[j][2] #Linea detector a buscar
    storey_search = sel_hits_ev_df.iloc[j][3] #Piso detector a buscar
    #Primero busqué por piso detector (me pareció que era más corto ya que son menos lineas)
    tempdf = raw_hits_ev_df.loc[raw_hits_ev_df['piso_det'].isin([storey_search])]
    #Posteriormente filtré por línea del detector
    tempdf = tempdf.loc[tempdf['lin_det'].isin([lindet_search])]
    #print(tempdf)
    for i in range(tempdf.shape[0]):
        temp = tempdf.iloc[i][5:11]
        if selp.equals(temp):
            df_hits=df_hits.append(tempdf.iloc[i])
        #print("\n")

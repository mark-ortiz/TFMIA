# %% [markdown]
# # NOTEBOOK PARA GENERAR EL DATAFRAME CON LA DATA DE TODOS LOS ARCHIVOS PARA AAFIT, BBFIT Y OTROS
#
# <font size=5>La data para los hits la generaré con otro Notebook.</font>
#
# Es importante mencionar que esta "limpieza" (generación del algoritmo) y obtención de data, me llevó aproximadamente 12 horas en general, desde el proceso creativo, pasando por la frustración, muchos intentos fallidos y hasta el momento de EUREKA!!!... XD.
#
# Borré ya la mayoría de celdas que me llevaron al código de las siguientes dos celdas, el cual está mucho más pulido y limpio, pero creo que es importente mencionar por lo que pase y las ideas (algunas locas) que me surgieron para poder resolverlo.
#
# Algunos ideas que tuve antes de llegar a decidir que no calcularia como tal el indice de aafit fueron:
# * Solo quedarme con los archivos que tuvieran 100% data completa (terrible idea ya que son más del 50% los archivos que en algunos eventos - alrededor del 5% o menos - no tienen data de aafit).
# * Verificar las longitudes de la cadena aafit y bbfit y comparar (idea bastante mala por cierto)
# * Tratar de buscar por separado en otra celda solo la data de aafit y "pegarla" de alguna manera al dataframe final, hay que decir que esta idea también fué muy mala y no prosperó en lo absoluto (creo no tenia ni pies ni cabeza, momento de frustración máxima).
#
# **NOTA:** Como siempre, la gran cuestión y prerrogativa humana es encontrar patrones en los datos y automatizar
# búsquedas aún y cuando estos no se vean a simple vista o no sean fácilmente inferibles, tales como cuando
# el patrón es precisamente eso... que NO HAY PATRÓN!!!, esto aplica para el no indice ind_aafit

# %%
#Recordando algunas variables importantes, funciones y librerías que se requerirán
import os
import pandas as pd
import re
import math

#extractpath = "U:\MASTER INT. ARTIFICIAL\TFM_DATA\TXTs" #Este path es para mi laptop en casa
#extractpath = "F:\\DATA_TFM\\TXTs" #Este path es para mi PC en el trabajo
extractpath = "Z:\MASTER INT. ARTIFICIAL\TFM_DATA\TXTs" #Este es para mi no tan nueva PC-Desktop

txtfilesarr = os.listdir(extractpath); txtfilesarr=sorted(txtfilesarr)
#csv_path = "F:\\DATA_TFM\\CSVs\\"
csv_path = "Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\\"
csvarr = os.listdir(csv_path);csvarr=sorted(csvarr)

# Funcion para obtener los indices de un archivo
def indices(df):
    ind_startev = [];ind_runid = [];ind_weights = [];ind_muon = []
    ind_bbfit = [];ind_bb_selp = [];ind_endev = [];#ind_aafit = []
    for i in range(data.shape[0]):
        tempstr = data[0][i]
        if "start_event" in tempstr: ind_startev.append(i)
        if "UTC" in tempstr: ind_runid.append(i)
        if "weights" in tempstr: ind_weights.append(i)
        if "muon" in tempstr: ind_muon.append(i)
        #if "aafit" in tempstr:  ##NO LO CALCULARE!!! OBTENDRE LOS VALORES DE OTRA FORMA
        #    ind_aafit.append(i) ##COMO TENGO EL INDICE DE BBFIT, RESTO 1 LINEA Y ASIGNO VALORES
        if "bbfit" in tempstr:   ##SEGUN LA EXISTENCIA O NO DE LA LINEA!!!! EUREKA!!!
            ind_bbfit.append(i)
        if "selected" in tempstr: ind_bb_selp.append(i)
        if "end_event" in tempstr: ind_endev.append(i)
    return(ind_startev,ind_runid,ind_weights,ind_muon,ind_bbfit,ind_bb_selp,ind_endev)

#Función para verificar si los indices tienen el mismo # de elementos
def longitudes(i1,i2,i3,i4,i5,i6,i7):
    a=len(i1);b=len(i2);c=len(i3);d=len(i4);e=len(i5);f=len(i6);g=len(i7)
    #print(a,b,c,d,e,f,g)
    if (a==b and b==c and c==d and d==e and e==f and f==g): return(True)
    else: return(False)
    return()

### NOTA: Como siempre, la gran cuestión y prerrogativa humana es encontrar patrones en los datos y automatizar
### búsquedas aún y cuando estos no se vean a simple vista o no sean fácilmente inferibles, tales como cuando 
### el patrón es precisamente eso... que NO HAY PATRÓN!!!, esto aplica para el no indice ind_aafit

# %% [markdown]
# ## Se requiere poder generar un algoritmo que sea más rápido que el anterior, que metía los datos directo a un dataframe con loc...
#
# <font size=4>Ideas:</font>
#
# 1. Generar una lista en vez de un dataframe y al final generar el dataframe, a ver si resulta más rápido.
#
# 2. Sacar la data de cada archivo CSV y generar otro archivo ya con la data filtrada, así si se reinicia la PC, al menos no se pierde toda el trabajo, unicamente el del archivo último.
#
# **NOTA:** Después de probar, la idea 1 funcionó muy bien, el tiempo de procesamiento de cada archivo, se redujo enormemente. Adicionalmente es muy importante mencionar que el uso de CPU de mi PC de casa no subió más allá del 50%, el anterior algoritmo que usaba el dataframe directo con loc, hacía que se fuera hasta el 100% de utilización.

# %%
############################################################################################################
###### ESTE CODIGO GENERARÁ UN DATAFRAME CON LA DATA DE BBFIT, AAFIT Y OTRAS DE ""TODOS"" LOS ARCHIVOS #####
############################################################################################################

#Se requiere un dataframe donde iremos guardando cada fila de data obtenida de cada archivo
columnas = ['runID','frameID','trigger_counter','interactionID','aafit_azimut',
            'aafit_zenit','aafit_lambda','aafit_beta','bbfit_azimut','bbfit_zenit','bbfit_quality',
            'muon_azimut','muon_zenit','muon_energy'] #La data del muon la añadi el 30 Jun, lo habia "olvidado" XD
data_df = pd.DataFrame(columns=columnas)
#La lista donde guardaremos los renglones antes de pasarla a dataframe
data_list = []

#Bucle para recorrer todos los archivos.
for k in range(len(csvarr)):
    file = csv_path+csvarr[k]
    #print("El archivo trabajando es: ",file,"eventos:",len(ind_))
    data = pd.read_csv(file, header=None) # Dataframe del archivo en tratamiento
    ind_startev = [];ind_runid = [];ind_weights = [];ind_muon = []
    ind_bbfit = [];ind_bb_selp = [];ind_endev = []
    #Generacion de indices para cada archivo
    ind_startev,ind_runid,ind_weights,ind_muon,ind_bbfit,ind_bb_selp,ind_endev = indices(data)
    print("El archivo trabajando es: ",file,"eventos:",len(ind_startev))
    #Como el runid es identico para todos los datos en un mismo archivo, uso el primero que aparece en el dataframe
    runID = int(list(str(data[0][ind_runid[0]]).split(" "))[0])
    #Igual como el interactionID es el mismo para todos, asigno 1 si el archivo es "numu" y 2 si es "anumu"
    interactionID = [lambda:1, lambda:2]["anumu" in str(file)]()
    #Bucle para recorrer el archivo en curso y obtener la data relevante
    print("Entrando al bucle para meter renglones a la lista") 
    for i in range(len(ind_startev)):
        #Codigo para obtener los demas datos por cada evento y despues asignarlo a los hits
        #Divido la cadena en los valores que la componen para después extraer frameid y trigger_counter
        temprunid = list(data[0][ind_runid[i]].split(" "))
        tempmuon = list(data[0][ind_muon[i]].split(" "))
        tempbbfit = list(data[0][ind_bbfit[i]].split(" "))
        #Extrayendo las variables frameid, trigger_counter de este renglon---> esta data si cambia ojo!!
        frameID = temprunid[1]; trigger_counter = temprunid [2]
        #Obteniendo y generando Datos para aafit
        #Para calcular la data solo haremos la diferencia y si exista data la calculamos si no
        #pues ponemos valores fuera de rango para saber después que no hubo data como -3pi
        laafit = data[0][ind_bbfit[i]-1]
        if "aafit" in laafit:
            tempaafit = list(data[0][ind_bbfit[i]-1].split(" "))
            aafit_azimut = math.atan2(float(tempaafit[3]),float(tempaafit[2]))
            aafit_zenit = math.acos(float(tempaafit[4]))
            aafit_lambda = tempaafit[-2]
            aafit_beta = tempaafit [-1]
        else:
            aafit_azimut=-3*math.pi;aafit_zenit = -3*math.pi;aafit_lambda=1;aafit_beta=-1
        #Obteniendo y generando Datos para bbfit
        X = float(tempbbfit[2]); Y = float(tempbbfit[3]); Z = float(tempbbfit[4])
        #Hay que verificar si X o Y son nan y asignar el valor de bbfit_azimut
        if math.isnan(X):   bbfit_azimut = -3*math.pi
        elif math.isnan(Y): bbfit_azimut = -3*math.pi
        else: bbfit_azimut = math.atan2(Y,X)
        bbfit_zenit = math.acos(Z)
        bbfit_quality = float(tempbbfit[-1]) 
        #Obteniendo y generando la data del muon
        X = float(tempmuon[1]); Y = float(tempmuon[2]); Z = float(tempmuon[3])
        muon_azimut = math.atan2(Y,X)
        muon_zenit = math.acos(Z)
        muon_energy = float(tempmuon[-2])
        #Añadimos la data obtenida y la generada a la lista "renglon"
        renglon = [runID, frameID, trigger_counter, interactionID,aafit_azimut, aafit_zenit,
                   aafit_lambda,aafit_beta, bbfit_azimut,bbfit_zenit,bbfit_quality,muon_azimut,muon_zenit,muon_energy]
        #Añadiendo los datos del "renglon" completo a la lista
        data_list.extend([renglon])

data_df = pd.DataFrame(data_list,columns=columnas)
print("Fin de la extracción de la data")
# Out:
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_025800_anumu_CC_a_reco.i3.csv eventos: 256
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_025800_numu_CC_a_reco.i3.csv eventos: 223
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_025880_anumu_CC_a_reco.i3.csv eventos: 271
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_025880_numu_CC_a_reco.i3.csv eventos: 230
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_025920_anumu_CC_a_reco.i3.csv eventos: 273
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_025920_numu_CC_a_reco.i3.csv eventos: 284
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_025930_anumu_CC_a_reco.i3.csv eventos: 200
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_025930_numu_CC_a_reco.i3.csv eventos: 176
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_025990_anumu_CC_a_reco.i3.csv eventos: 146
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_025990_numu_CC_a_reco.i3.csv eventos: 119
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026010_anumu_CC_a_reco.i3.csv eventos: 132
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026010_numu_CC_a_reco.i3.csv eventos: 127
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026030_anumu_CC_a_reco.i3.csv eventos: 24
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026030_numu_CC_a_reco.i3.csv eventos: 22
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026110_anumu_CC_a_reco.i3.csv eventos: 143
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026110_numu_CC_a_reco.i3.csv eventos: 134
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026160_anumu_CC_a_reco.i3.csv eventos: 282
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026160_numu_CC_a_reco.i3.csv eventos: 256
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026190_anumu_CC_a_reco.i3.csv eventos: 275
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026190_numu_CC_a_reco.i3.csv eventos: 285
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026230_anumu_CC_a_reco.i3.csv eventos: 295
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026230_numu_CC_a_reco.i3.csv eventos: 252
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026270_anumu_CC_a_reco.i3.csv eventos: 257
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026270_numu_CC_a_reco.i3.csv eventos: 217
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026340_anumu_CC_a_reco.i3.csv eventos: 276
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026340_numu_CC_a_reco.i3.csv eventos: 228
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026470_anumu_CC_a_reco.i3.csv eventos: 214
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026470_numu_CC_a_reco.i3.csv eventos: 228
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026480_anumu_CC_a_reco.i3.csv eventos: 218
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026480_numu_CC_a_reco.i3.csv eventos: 207
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026540_anumu_CC_a_reco.i3.csv eventos: 247
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026540_numu_CC_a_reco.i3.csv eventos: 235
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026640_anumu_CC_a_reco.i3.csv eventos: 218
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026640_numu_CC_a_reco.i3.csv eventos: 160
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026660_anumu_CC_a_reco.i3.csv eventos: 210
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026660_numu_CC_a_reco.i3.csv eventos: 179
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026710_anumu_CC_a_reco.i3.csv eventos: 200
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026710_numu_CC_a_reco.i3.csv eventos: 214
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026720_anumu_CC_a_reco.i3.csv eventos: 131
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026720_numu_CC_a_reco.i3.csv eventos: 148
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026770_anumu_CC_a_reco.i3.csv eventos: 118
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026770_numu_CC_a_reco.i3.csv eventos: 120
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026800_anumu_CC_a_reco.i3.csv eventos: 219
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026800_numu_CC_a_reco.i3.csv eventos: 180
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026810_anumu_CC_a_reco.i3.csv eventos: 210
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026810_numu_CC_a_reco.i3.csv eventos: 178
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026820_anumu_CC_a_reco.i3.csv eventos: 250
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026820_numu_CC_a_reco.i3.csv eventos: 229
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026830_anumu_CC_a_reco.i3.csv eventos: 270
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026830_numu_CC_a_reco.i3.csv eventos: 227
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026870_anumu_CC_a_reco.i3.csv eventos: 261
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026870_numu_CC_a_reco.i3.csv eventos: 263
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026920_anumu_CC_a_reco.i3.csv eventos: 248
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026920_numu_CC_a_reco.i3.csv eventos: 213
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026940_anumu_CC_a_reco.i3.csv eventos: 320
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026940_numu_CC_a_reco.i3.csv eventos: 307
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026970_anumu_CC_a_reco.i3.csv eventos: 305
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_026970_numu_CC_a_reco.i3.csv eventos: 298
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027080_anumu_CC_a_reco.i3.csv eventos: 172
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027080_numu_CC_a_reco.i3.csv eventos: 186
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027090_anumu_CC_a_reco.i3.csv eventos: 196
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027090_numu_CC_a_reco.i3.csv eventos: 179
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027100_anumu_CC_a_reco.i3.csv eventos: 276
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027100_numu_CC_a_reco.i3.csv eventos: 257
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027130_anumu_CC_a_reco.i3.csv eventos: 268
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027130_numu_CC_a_reco.i3.csv eventos: 282
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027170_anumu_CC_a_reco.i3.csv eventos: 294
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027170_numu_CC_a_reco.i3.csv eventos: 257
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027180_anumu_CC_a_reco.i3.csv eventos: 226
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027180_numu_CC_a_reco.i3.csv eventos: 187
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027230_anumu_CC_a_reco.i3.csv eventos: 261
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027230_numu_CC_a_reco.i3.csv eventos: 215
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027270_anumu_CC_a_reco.i3.csv eventos: 269
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027270_numu_CC_a_reco.i3.csv eventos: 290
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027290_anumu_CC_a_reco.i3.csv eventos: 269
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027290_numu_CC_a_reco.i3.csv eventos: 273
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027440_anumu_CC_a_reco.i3.csv eventos: 274
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027440_numu_CC_a_reco.i3.csv eventos: 263
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027460_anumu_CC_a_reco.i3.csv eventos: 313
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027460_numu_CC_a_reco.i3.csv eventos: 300
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027470_anumu_CC_a_reco.i3.csv eventos: 283
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027470_numu_CC_a_reco.i3.csv eventos: 257
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027550_anumu_CC_a_reco.i3.csv eventos: 240
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027550_numu_CC_a_reco.i3.csv eventos: 260
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027580_anumu_CC_a_reco.i3.csv eventos: 218
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027580_numu_CC_a_reco.i3.csv eventos: 242
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027620_anumu_CC_a_reco.i3.csv eventos: 158
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027620_numu_CC_a_reco.i3.csv eventos: 156
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027640_anumu_CC_a_reco.i3.csv eventos: 371
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027640_numu_CC_a_reco.i3.csv eventos: 343
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027660_anumu_CC_a_reco.i3.csv eventos: 89
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027660_numu_CC_a_reco.i3.csv eventos: 91
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027720_anumu_CC_a_reco.i3.csv eventos: 27
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027720_numu_CC_a_reco.i3.csv eventos: 22
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027750_anumu_CC_a_reco.i3.csv eventos: 281
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027750_numu_CC_a_reco.i3.csv eventos: 273
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027760_anumu_CC_a_reco.i3.csv eventos: 284
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027760_numu_CC_a_reco.i3.csv eventos: 286
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027830_anumu_CC_a_reco.i3.csv eventos: 273
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027830_numu_CC_a_reco.i3.csv eventos: 253
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027890_anumu_CC_a_reco.i3.csv eventos: 291
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027890_numu_CC_a_reco.i3.csv eventos: 306
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027900_anumu_CC_a_reco.i3.csv eventos: 249
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027900_numu_CC_a_reco.i3.csv eventos: 262
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027980_anumu_CC_a_reco.i3.csv eventos: 365
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027980_numu_CC_a_reco.i3.csv eventos: 392
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027990_anumu_CC_a_reco.i3.csv eventos: 369
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_027990_numu_CC_a_reco.i3.csv eventos: 321
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028070_anumu_CC_a_reco.i3.csv eventos: 329
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028070_numu_CC_a_reco.i3.csv eventos: 322
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028110_anumu_CC_a_reco.i3.csv eventos: 339
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028110_numu_CC_a_reco.i3.csv eventos: 314
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028280_anumu_CC_a_reco.i3.csv eventos: 371
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028280_numu_CC_a_reco.i3.csv eventos: 363
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028340_anumu_CC_a_reco.i3.csv eventos: 334
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028340_numu_CC_a_reco.i3.csv eventos: 330
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028350_anumu_CC_a_reco.i3.csv eventos: 325
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028350_numu_CC_a_reco.i3.csv eventos: 270
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028450_anumu_CC_a_reco.i3.csv eventos: 388
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028450_numu_CC_a_reco.i3.csv eventos: 326
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028460_anumu_CC_a_reco.i3.csv eventos: 330
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028460_numu_CC_a_reco.i3.csv eventos: 337
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028510_anumu_CC_a_reco.i3.csv eventos: 280
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028510_numu_CC_a_reco.i3.csv eventos: 265
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028570_anumu_CC_a_reco.i3.csv eventos: 194
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028570_numu_CC_a_reco.i3.csv eventos: 148
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028620_anumu_CC_a_reco.i3.csv eventos: 238
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028620_numu_CC_a_reco.i3.csv eventos: 206
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028630_anumu_CC_a_reco.i3.csv eventos: 317
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028630_numu_CC_a_reco.i3.csv eventos: 286
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028650_anumu_CC_a_reco.i3.csv eventos: 324
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028650_numu_CC_a_reco.i3.csv eventos: 351
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028720_anumu_CC_a_reco.i3.csv eventos: 301
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028720_numu_CC_a_reco.i3.csv eventos: 296
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028730_anumu_CC_a_reco.i3.csv eventos: 357
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028730_numu_CC_a_reco.i3.csv eventos: 317
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028770_anumu_CC_a_reco.i3.csv eventos: 293
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028770_numu_CC_a_reco.i3.csv eventos: 271
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028780_anumu_CC_a_reco.i3.csv eventos: 305
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028780_numu_CC_a_reco.i3.csv eventos: 331
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028790_anumu_CC_a_reco.i3.csv eventos: 480
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028790_numu_CC_a_reco.i3.csv eventos: 468
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028850_anumu_CC_a_reco.i3.csv eventos: 389
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028850_numu_CC_a_reco.i3.csv eventos: 377
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028860_anumu_CC_a_reco.i3.csv eventos: 405
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028860_numu_CC_a_reco.i3.csv eventos: 357
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028870_anumu_CC_a_reco.i3.csv eventos: 360
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028870_numu_CC_a_reco.i3.csv eventos: 341
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028950_anumu_CC_a_reco.i3.csv eventos: 426
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028950_numu_CC_a_reco.i3.csv eventos: 431
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028970_anumu_CC_a_reco.i3.csv eventos: 473
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028970_numu_CC_a_reco.i3.csv eventos: 405
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028980_anumu_CC_a_reco.i3.csv eventos: 360
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028980_numu_CC_a_reco.i3.csv eventos: 350
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028990_anumu_CC_a_reco.i3.csv eventos: 355
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_028990_numu_CC_a_reco.i3.csv eventos: 316
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029040_anumu_CC_a_reco.i3.csv eventos: 308
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029040_numu_CC_a_reco.i3.csv eventos: 284
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029050_anumu_CC_a_reco.i3.csv eventos: 409
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029050_numu_CC_a_reco.i3.csv eventos: 360
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029060_anumu_CC_a_reco.i3.csv eventos: 332
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029060_numu_CC_a_reco.i3.csv eventos: 331
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029100_anumu_CC_a_reco.i3.csv eventos: 298
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029100_numu_CC_a_reco.i3.csv eventos: 328
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029110_anumu_CC_a_reco.i3.csv eventos: 424
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029110_numu_CC_a_reco.i3.csv eventos: 372
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029120_anumu_CC_a_reco.i3.csv eventos: 455
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029120_numu_CC_a_reco.i3.csv eventos: 430
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029160_anumu_CC_a_reco.i3.csv eventos: 387
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029160_numu_CC_a_reco.i3.csv eventos: 334
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029180_anumu_CC_a_reco.i3.csv eventos: 368
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029180_numu_CC_a_reco.i3.csv eventos: 374
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029190_anumu_CC_a_reco.i3.csv eventos: 469
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029190_numu_CC_a_reco.i3.csv eventos: 394
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029220_anumu_CC_a_reco.i3.csv eventos: 313
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029220_numu_CC_a_reco.i3.csv eventos: 293
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029250_anumu_CC_a_reco.i3.csv eventos: 301
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029250_numu_CC_a_reco.i3.csv eventos: 315
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029270_anumu_CC_a_reco.i3.csv eventos: 297
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029270_numu_CC_a_reco.i3.csv eventos: 271
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029280_anumu_CC_a_reco.i3.csv eventos: 268
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029280_numu_CC_a_reco.i3.csv eventos: 290
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029320_anumu_CC_a_reco.i3.csv eventos: 263
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029320_numu_CC_a_reco.i3.csv eventos: 285
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029330_anumu_CC_a_reco.i3.csv eventos: 306
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029330_numu_CC_a_reco.i3.csv eventos: 284
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029350_anumu_CC_a_reco.i3.csv eventos: 320
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029350_numu_CC_a_reco.i3.csv eventos: 291
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029360_anumu_CC_a_reco.i3.csv eventos: 318
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029360_numu_CC_a_reco.i3.csv eventos: 286
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029370_anumu_CC_a_reco.i3.csv eventos: 288
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029370_numu_CC_a_reco.i3.csv eventos: 286
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029420_anumu_CC_a_reco.i3.csv eventos: 399
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029420_numu_CC_a_reco.i3.csv eventos: 322
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029440_anumu_CC_a_reco.i3.csv eventos: 312
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029440_numu_CC_a_reco.i3.csv eventos: 309
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029480_anumu_CC_a_reco.i3.csv eventos: 256
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029480_numu_CC_a_reco.i3.csv eventos: 226
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029490_anumu_CC_a_reco.i3.csv eventos: 204
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029490_numu_CC_a_reco.i3.csv eventos: 197
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029500_anumu_CC_a_reco.i3.csv eventos: 243
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029500_numu_CC_a_reco.i3.csv eventos: 230
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029540_anumu_CC_a_reco.i3.csv eventos: 186
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029540_numu_CC_a_reco.i3.csv eventos: 153
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029580_anumu_CC_a_reco.i3.csv eventos: 284
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029580_numu_CC_a_reco.i3.csv eventos: 230
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029600_anumu_CC_a_reco.i3.csv eventos: 279
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029600_numu_CC_a_reco.i3.csv eventos: 236
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029740_anumu_CC_a_reco.i3.csv eventos: 271
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029740_numu_CC_a_reco.i3.csv eventos: 265
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029760_anumu_CC_a_reco.i3.csv eventos: 290
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029760_numu_CC_a_reco.i3.csv eventos: 298
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029790_anumu_CC_a_reco.i3.csv eventos: 369
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029790_numu_CC_a_reco.i3.csv eventos: 351
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029810_anumu_CC_a_reco.i3.csv eventos: 401
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029810_numu_CC_a_reco.i3.csv eventos: 341
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029820_anumu_CC_a_reco.i3.csv eventos: 249
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029820_numu_CC_a_reco.i3.csv eventos: 286
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029830_anumu_CC_a_reco.i3.csv eventos: 382
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029830_numu_CC_a_reco.i3.csv eventos: 362
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029840_anumu_CC_a_reco.i3.csv eventos: 392
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029840_numu_CC_a_reco.i3.csv eventos: 372
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029910_anumu_CC_a_reco.i3.csv eventos: 379
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029910_numu_CC_a_reco.i3.csv eventos: 380
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029920_anumu_CC_a_reco.i3.csv eventos: 384
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029920_numu_CC_a_reco.i3.csv eventos: 401
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029980_anumu_CC_a_reco.i3.csv eventos: 423
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_029980_numu_CC_a_reco.i3.csv eventos: 414
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030020_anumu_CC_a_reco.i3.csv eventos: 433
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030020_numu_CC_a_reco.i3.csv eventos: 354
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030030_anumu_CC_a_reco.i3.csv eventos: 387
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030030_numu_CC_a_reco.i3.csv eventos: 397
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030060_anumu_CC_a_reco.i3.csv eventos: 399
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030060_numu_CC_a_reco.i3.csv eventos: 371
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030070_anumu_CC_a_reco.i3.csv eventos: 444
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030070_numu_CC_a_reco.i3.csv eventos: 447
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030080_anumu_CC_a_reco.i3.csv eventos: 451
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030080_numu_CC_a_reco.i3.csv eventos: 441
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030090_anumu_CC_a_reco.i3.csv eventos: 337
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030090_numu_CC_a_reco.i3.csv eventos: 353
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030100_anumu_CC_a_reco.i3.csv eventos: 380
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030100_numu_CC_a_reco.i3.csv eventos: 325
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030110_anumu_CC_a_reco.i3.csv eventos: 249
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030110_numu_CC_a_reco.i3.csv eventos: 245
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030120_anumu_CC_a_reco.i3.csv eventos: 277
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030120_numu_CC_a_reco.i3.csv eventos: 287
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030140_anumu_CC_a_reco.i3.csv eventos: 190
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030140_numu_CC_a_reco.i3.csv eventos: 187
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030150_anumu_CC_a_reco.i3.csv eventos: 355
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030150_numu_CC_a_reco.i3.csv eventos: 307
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030160_anumu_CC_a_reco.i3.csv eventos: 328
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030160_numu_CC_a_reco.i3.csv eventos: 337
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030170_anumu_CC_a_reco.i3.csv eventos: 387
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030170_numu_CC_a_reco.i3.csv eventos: 348
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030210_anumu_CC_a_reco.i3.csv eventos: 299
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030210_numu_CC_a_reco.i3.csv eventos: 275
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030220_anumu_CC_a_reco.i3.csv eventos: 318
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030220_numu_CC_a_reco.i3.csv eventos: 291
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030240_anumu_CC_a_reco.i3.csv eventos: 305
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030240_numu_CC_a_reco.i3.csv eventos: 282
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030310_anumu_CC_a_reco.i3.csv eventos: 301
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030310_numu_CC_a_reco.i3.csv eventos: 281
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030320_anumu_CC_a_reco.i3.csv eventos: 381
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030320_numu_CC_a_reco.i3.csv eventos: 322
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030340_anumu_CC_a_reco.i3.csv eventos: 350
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030340_numu_CC_a_reco.i3.csv eventos: 298
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030370_anumu_CC_a_reco.i3.csv eventos: 278
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030370_numu_CC_a_reco.i3.csv eventos: 266
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030380_anumu_CC_a_reco.i3.csv eventos: 347
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030380_numu_CC_a_reco.i3.csv eventos: 311
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030390_anumu_CC_a_reco.i3.csv eventos: 272
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030390_numu_CC_a_reco.i3.csv eventos: 268
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030410_anumu_CC_a_reco.i3.csv eventos: 188
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030410_numu_CC_a_reco.i3.csv eventos: 200
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030430_anumu_CC_a_reco.i3.csv eventos: 300
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030430_numu_CC_a_reco.i3.csv eventos: 250
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030440_anumu_CC_a_reco.i3.csv eventos: 310
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030440_numu_CC_a_reco.i3.csv eventos: 302
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030450_anumu_CC_a_reco.i3.csv eventos: 278
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030450_numu_CC_a_reco.i3.csv eventos: 287
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030460_anumu_CC_a_reco.i3.csv eventos: 227
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030460_numu_CC_a_reco.i3.csv eventos: 237
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030880_anumu_CC_a_reco.i3.csv eventos: 798
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030880_numu_CC_a_reco.i3.csv eventos: 705
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030950_anumu_CC_a_reco.i3.csv eventos: 670
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030950_numu_CC_a_reco.i3.csv eventos: 596
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030970_anumu_CC_a_reco.i3.csv eventos: 643
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_030970_numu_CC_a_reco.i3.csv eventos: 611
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_031000_anumu_CC_a_reco.i3.csv eventos: 687
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_031000_numu_CC_a_reco.i3.csv eventos: 654
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_031010_anumu_CC_a_reco.i3.csv eventos: 720
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_031010_numu_CC_a_reco.i3.csv eventos: 637
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_031020_anumu_CC_a_reco.i3.csv eventos: 712
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_031020_numu_CC_a_reco.i3.csv eventos: 667
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_031030_anumu_CC_a_reco.i3.csv eventos: 740
# Entrando al bucle para meter renglones a la lista
# ...
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_055920_numu_CC_a_reco.i3.csv eventos: 1216
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_055950_anumu_CC_a_reco.i3.csv eventos: 542
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_055950_numu_CC_a_reco.i3.csv eventos: 533
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_055990_anumu_CC_a_reco.i3.csv eventos: 723
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_055990_numu_CC_a_reco.i3.csv eventos: 636
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_056010_anumu_CC_a_reco.i3.csv eventos: 386
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_056010_numu_CC_a_reco.i3.csv eventos: 379
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_056200_anumu_CC_a_reco.i3.csv eventos: 1843
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_056200_numu_CC_a_reco.i3.csv eventos: 1668
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_056220_anumu_CC_a_reco.i3.csv eventos: 1869
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_056440_anumu_CC_a_reco.i3.csv eventos: 1390
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_056440_numu_CC_a_reco.i3.csv eventos: 1325
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_056450_anumu_CC_a_reco.i3.csv eventos: 452
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_056450_numu_CC_a_reco.i3.csv eventos: 441
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_056570_anumu_CC_a_reco.i3.csv eventos: 1002
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_056570_numu_CC_a_reco.i3.csv eventos: 870
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_056600_anumu_CC_a_reco.i3.csv eventos: 930
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_056600_numu_CC_a_reco.i3.csv eventos: 881
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_056610_anumu_CC_a_reco.i3.csv eventos: 546
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_056610_numu_CC_a_reco.i3.csv eventos: 568
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_056670_anumu_CC_a_reco.i3.csv eventos: 917
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_056670_numu_CC_a_reco.i3.csv eventos: 874
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_056680_anumu_CC_a_reco.i3.csv eventos: 589
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_056680_numu_CC_a_reco.i3.csv eventos: 511
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_056690_anumu_CC_a_reco.i3.csv eventos: 1079
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_056760_numu_CC_a_reco.i3.csv eventos: 1592
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_056800_numu_CC_a_reco.i3.csv eventos: 1632
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057060_anumu_CC_a_reco.i3.csv eventos: 574
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057060_numu_CC_a_reco.i3.csv eventos: 573
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057110_anumu_CC_a_reco.i3.csv eventos: 771
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057110_numu_CC_a_reco.i3.csv eventos: 710
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057130_anumu_CC_a_reco.i3.csv eventos: 730
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057130_numu_CC_a_reco.i3.csv eventos: 672
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057240_numu_CC_a_reco.i3.csv eventos: 743
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057250_anumu_CC_a_reco.i3.csv eventos: 985
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057260_anumu_CC_a_reco.i3.csv eventos: 1050
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057260_numu_CC_a_reco.i3.csv eventos: 1015
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057370_anumu_CC_a_reco.i3.csv eventos: 1228
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057370_numu_CC_a_reco.i3.csv eventos: 1165
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057380_anumu_CC_a_reco.i3.csv eventos: 1270
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057380_numu_CC_a_reco.i3.csv eventos: 1128
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057400_anumu_CC_a_reco.i3.csv eventos: 989
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057400_numu_CC_a_reco.i3.csv eventos: 977
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057410_anumu_CC_a_reco.i3.csv eventos: 1115
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057410_numu_CC_a_reco.i3.csv eventos: 990
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057420_anumu_CC_a_reco.i3.csv eventos: 1209
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057420_numu_CC_a_reco.i3.csv eventos: 15
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057440_anumu_CC_a_reco.i3.csv eventos: 1326
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057440_numu_CC_a_reco.i3.csv eventos: 1150
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057470_anumu_CC_a_reco.i3.csv eventos: 1172
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057470_numu_CC_a_reco.i3.csv eventos: 1104
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057590_numu_CC_a_reco.i3.csv eventos: 1228
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057610_anumu_CC_a_reco.i3.csv eventos: 1341
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057610_numu_CC_a_reco.i3.csv eventos: 1250
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057650_anumu_CC_a_reco.i3.csv eventos: 1468
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057650_numu_CC_a_reco.i3.csv eventos: 1318
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057660_anumu_CC_a_reco.i3.csv eventos: 1520
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057660_numu_CC_a_reco.i3.csv eventos: 1335
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057690_anumu_CC_a_reco.i3.csv eventos: 1712
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057690_numu_CC_a_reco.i3.csv eventos: 1601
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057700_numu_CC_a_reco.i3.csv eventos: 1579
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_057710_anumu_CC_a_reco.i3.csv eventos: 1717
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058080_anumu_CC_a_reco.i3.csv eventos: 1682
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058090_anumu_CC_a_reco.i3.csv eventos: 1613
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058090_numu_CC_a_reco.i3.csv eventos: 1510
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058110_anumu_CC_a_reco.i3.csv eventos: 1524
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058110_numu_CC_a_reco.i3.csv eventos: 1364
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058130_numu_CC_a_reco.i3.csv eventos: 1423
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058140_anumu_CC_a_reco.i3.csv eventos: 1521
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058150_anumu_CC_a_reco.i3.csv eventos: 1569
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058260_numu_CC_a_reco.i3.csv eventos: 928
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058280_anumu_CC_a_reco.i3.csv eventos: 864
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058280_numu_CC_a_reco.i3.csv eventos: 782
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058290_numu_CC_a_reco.i3.csv eventos: 811
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058300_anumu_CC_a_reco.i3.csv eventos: 623
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058300_numu_CC_a_reco.i3.csv eventos: 627
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058310_anumu_CC_a_reco.i3.csv eventos: 572
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058310_numu_CC_a_reco.i3.csv eventos: 557
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058370_anumu_CC_a_reco.i3.csv eventos: 1251
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058370_numu_CC_a_reco.i3.csv eventos: 1202
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058420_numu_CC_a_reco.i3.csv eventos: 1216
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058430_numu_CC_a_reco.i3.csv eventos: 1271
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058440_anumu_CC_a_reco.i3.csv eventos: 1249
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058510_anumu_CC_a_reco.i3.csv eventos: 948
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058510_numu_CC_a_reco.i3.csv eventos: 970
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058540_anumu_CC_a_reco.i3.csv eventos: 1253
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058540_numu_CC_a_reco.i3.csv eventos: 1250
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058550_anumu_CC_a_reco.i3.csv eventos: 1472
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058560_anumu_CC_a_reco.i3.csv eventos: 1299
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058560_numu_CC_a_reco.i3.csv eventos: 1205
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058570_anumu_CC_a_reco.i3.csv eventos: 1332
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058570_numu_CC_a_reco.i3.csv eventos: 1395
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058590_anumu_CC_a_reco.i3.csv eventos: 1755
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058590_numu_CC_a_reco.i3.csv eventos: 1608
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058620_anumu_CC_a_reco.i3.csv eventos: 1530
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058710_numu_CC_a_reco.i3.csv eventos: 1407
# Entrando al bucle para meter renglones a la lista
# El archivo trabajando es:  Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CSVs\MC_058730_anumu_CC_a_reco.i3.csv eventos: 1555
# Entrando al bucle para meter renglones a la lista
# Fin de la extracción de la data

# %%
print(data_df.shape[0])
data_df.sample(10)
# Out:
# 1021092
#          runID frameID trigger_counter  interactionID  aafit_azimut  \
# 1010499  58560   27028            1834              1      0.628684
# 864273   54740    4348            1922              2      2.531675
# 210239   34640    5604            1252              1     -1.230033
# 886522   55020   19982            2030              1      2.899592
# 690038   51710    2903            1384              1     -1.175720
# 106327   31700    3645              21              2      2.562168
# 534215   46500   12095            1463              2      0.468708
# 952391   57400   23116             956              2     -2.655224
# 759423   53230   50307            2604              2     -9.424778
# 600888   49420  109611             834              2     -1.388765
#
#          aafit_zenit    aafit_lambda        aafit_beta  bbfit_azimut  \
# 1010499     1.966673  -5.43218625997  0.00961232852203      0.791417
# 864273      0.430251  -6.81586459849   0.0103359031197     -9.424778
# 210239      0.855468  -4.96529444621  0.00691384423233     -1.120634
# 886522      0.367717  -6.92335391621  0.00910323574625     -9.424778
# 690038      0.630231  -6.69792543436   0.0371529536145     -9.424778
# 106327      1.044096  -6.64587654433   0.0216043462662     -9.424778
# 534215      1.363939  -5.68214342732   0.0509787565364      0.396880
# 952391      1.588238   -6.7207501619   0.0556673401526     -1.524424
# 759423     -9.424778               1                -1     -9.424778
# 600888      0.552878  -6.47635758938    0.016021166497     -9.424778
#
#          bbfit_zenit  bbfit_quality  muon_azimut  muon_zenit  muon_energy
# 1010499     1.956598       5.591500     0.645242    1.965992  16337.70000
# 864273      0.663012       2.286900     3.099454    0.857576     46.25450
# 210239      0.915423       3.388764    -1.231596    0.863373    198.58000
# 886522      1.684303       3.537956    -0.246576    1.905766      1.67972
# 690038      1.011595       2.518997    -1.710641    1.042106    370.16500
# 106327      0.667270       2.987966    -2.886021    0.688583     30.13940
# 534215      1.531517       3.075022    -0.296668    1.649453    144.44300
# 952391      1.594477       5.158282    -0.898833    2.367010      7.55189
# 759423      0.774384       3.170686    -2.620460    1.169140     86.25550
# 600888      0.840145       2.403417     1.792524    1.149187    112.26700

# %%
## Una vez que tenemos el dataframe con toda la data relevante de aafit y bbfit
## debemos guardar esta data a disco

outputpath = "Z:\MASTER INT. ARTIFICIAL\TFM_DATA\CLEANDATA\\"
    
data_df.to_csv (outputpath+"data_aafit_bbfit_muon"+".csv", index = None)#, header=None)

#Nota: Empezó a las 2:15pm del 30 Jun para 1136 archivos pero trono por actualizaciones el 3 Jul a las 7:20 p.m.
#Volvi a correr el proceso con listas y tardo de las 8:30p.m. a las 11:45 p.m. del 3 de Jul, con listas es wow!!

# %% [markdown]
# ## NOTA MUY IMPORTANTE
#
# De aquí en adelante, ya no utilicé el código, ya que este fue mi primer intento y utiliza un dataframe para guardar la data, sin embargo es extremadamente lento, yo pienso que porque utilicé la función loc. Lo que es muy cierto es que reutilicé la mayor parte y solo cambie la parte del dataframe, haciendo la asignación hasta el final.
#
# Dejé el código y las celdas sólo como evidencia e historial de lo que he venido haciendo.
#
# Ver el siguiente artículo: https://towardsdatascience.com/different-ways-to-iterate-over-rows-in-a-pandas-dataframe-performance-comparison-dc0d5dcef8fe

# %%
############################################################################################################
###### ESTE CODIGO GENERARÁ UN DATAFRAME CON LA DATA DE BBFIT, AAFIT Y OTRAS DE ""TODOS"" LOS ARCHIVOS #####
############################################################################################################

#Se requiere un dataframe donde iremos guardando cada fila de data obtenida de cada archivo
columnas = ['runID','frameID','trigger_counter','interactionID','aafit_azimut',
            'aafit_zenit','aafit_lambda','aafit_beta','bbfit_azimut','bbfit_zenit','bbfit_quality',
            'muon_azimut','muon_zenit','muon_energy'] #La data del muon la añadi el 30 Jun, lo habia "olvidado" XD
df_data1 = pd.DataFrame(columns=columnas)

consecutivo=0 #variable auxiliar para guardar el indice del ultimo elemento del archivo

# Bucle para recorrer TODOS los archivos y obtener la data y metadata de TODOS
for k in range(len(csvarr)):
    #print("Ciclo", k)
    file = csv_path+csvarr[k]
    print("El archivo trabajando es: ",file)
    data = pd.read_csv(file, header=None) # Dataframe del archivo en tratamiento
    ind_startev = [];ind_runid = [];ind_weights = [];ind_muon = []
    ind_bbfit = [];ind_bb_selp = [];ind_endev = []

    #Generacion de indices para cada archivo
    ind_startev,ind_runid,ind_weights,ind_muon,ind_bbfit,ind_bb_selp,ind_endev = indices(data)

    #Como el runid es identico para todos los datos en un mismo archivo, uso el primero que aparece en el dataframe
    runID = int(list(str(data[0][ind_runid[0]]).split(" "))[0])
    #Igual como el interactionID es el mismo para todos, asigno 1 si el archivo es "numu" y 2 si es "anumu"
    interactionID = [lambda:1, lambda:2]["anumu" in str(file)]()
    # Bucle para recorrer el archivo en curso y obtener la data relevante
    print("Entrando al bucle para meter renglones al dataframe") 
    for i in range(len(ind_startev)):
        #Codigo para obtener los demas datos por cada evento y despues asignarlo a los hits
        #Divido la cadena en los valores que la componen para después extraer frameid y trigger_counter
        temprunid = list(data[0][ind_runid[i]].split(" "))
        tempmuon = list(data[0][ind_muon[i]].split(" "))
        tempbbfit = list(data[0][ind_bbfit[i]].split(" "))
        #Extrayendo las variables frameid, trigger_counter de este renglon---> esta data si cambia ojo!!
        frameID = temprunid[1]; trigger_counter = temprunid [2]
        #Obteniendo y generando Datos para aafit
        #Para calcular la data solo haremos la diferencia y si exista data la calculamos si no
        #pues ponemos valores fuera de rango para saber después que no hubo data como -3pi
        laafit = data[0][ind_bbfit[i]-1]
        if "aafit" in laafit:
            tempaafit = list(data[0][ind_bbfit[i]-1].split(" "))
            aafit_azimut = math.atan2(float(tempaafit[3]),float(tempaafit[2]))
            aafit_zenit = math.acos(float(tempaafit[4]))
            aafit_lambda = tempaafit[-2]
            aafit_beta = tempaafit [-1]
        else:
            aafit_azimut=-3*math.pi;aafit_zenit = -3*math.pi;aafit_lambda=1;aafit_beta=-1
        #Obteniendo y generando Datos para bbfit
        X = float(tempbbfit[2]); Y = float(tempbbfit[3]); Z = float(tempbbfit[4])
        #Hay que verificar si X o Y son nan y asignar el valor de bbfit_azimut
        if math.isnan(X):   bbfit_azimut = -3*math.pi
        elif math.isnan(Y): bbfit_azimut = -3*math.pi
        else: bbfit_azimut = math.atan2(Y,X)
        bbfit_zenit = math.acos(Z)
        bbfit_quality = float(tempbbfit[-1]) 
        #Obteniendo y generando la data del muon
        X = float(tempmuon[1]); Y = float(tempmuon[2]); Z = float(tempmuon[3])
        muon_azimut = math.atan2(Y,X)
        muon_zenit = math.acos(Z)
        muon_energy = float(tempmuon[-2])
        #Añadimos la data obtenida y la generada al dataframe
        renglon = [runID, frameID, trigger_counter, interactionID,aafit_azimut, aafit_zenit,
                   aafit_lambda,aafit_beta, bbfit_azimut,bbfit_zenit,bbfit_quality,muon_azimut,muon_zenit,muon_energy]
        #Añadiendo datos al dataframe.
        df_data1.loc[i+consecutivo] = renglon
    consecutivo = df_data1.shape[0]

print("Fin de la extracción de la data")

# %%
### PRUEBAS... BORRAR ESTA CELDA AL FINAL

#Viendo como quedó el dataframe
print("El número de filas del dataframe es:", df_data1.shape[0])

print("Una muestra de las filas y la data en ellas")

df_data1.sample(10)

#df_data1.iloc[0:250]

# %% [markdown]
# # EL SIGUIENTE CÓDIGO NO ES NECESARIO PERO LO DEJÉ COMO EVIDENCIA DE LO QUE HABÍA ESTADO HACIENDO INICIALMENTE

# %%
##########################################################################################
####  ESTE CODIGO CONTIENE EL PRIMER ALGORITMO QUE GENERÉ PARA OBTENER LA DATA DE      ###
####  UN ARCHIVO CSV YA CON TRATAMIENTO "INICIAL", ES DECIR SIN LINEAS VACIAS Y OTRAS  ### 
####          ESTABA DIVIDIDO EN DOS CELDAS POR TODO EL TESTING QUE HICE               ###
##########################################################################################

    ####  #####  #####  #####  #####
    ##    ####   ####   #   #  ####
    ####  #   #  #   #  #####  #   #
    
# -->ESTE ALGORITMO TUVO UN FALLO FUNDAMENTAL... NO TOMABA EN CUENTA QUE HAY ARCHIVOS QUE NO TIENEN DATA DE AAFIT
# -->Sin embargo me sirvió como base primaria para generar el adecuado (2da. celda de arriba a abajo de este notebook)

file = csv_path+csvarr[1]
print("El archivo trabajando es: ",file)
data = pd.read_csv(file, header=None) # Dataframe del archivo en tratamiento
ind_startev = [];ind_runid = [];ind_weights = [];ind_muon = []
ind_aafit = [];ind_bbfit = [];ind_bb_selp = [];ind_endev = []

for i in range(data.shape[0]):
    tempstr = data[0][i]
    if "start_event" in tempstr:
        ind_startev.append(i)
    if "UTC" in tempstr:
        ind_runid.append(i)
    if "weights" in tempstr:
        ind_weights.append(i)
    if "muon" in tempstr:
        ind_muon.append(i)
    if "aafit" in tempstr:
        ind_aafit.append(i)
    if "bbfit" in tempstr:
        ind_bbfit.append(i)
    if "selected" in tempstr:
        ind_bb_selp.append(i)
    if "end_event" in tempstr:
        ind_endev.append(i)

####### YA QUE LOGRE GENERAR EL DATAFRAME PARA LOS DATOS DE AAFIT Y BBBFIT DE UN SOLO EVENTO,
####### AHORA LO HARÉ PARA TODOS LOS EVENTOS EN EL MISMO ARCHIVO
####### CODIGO PARA OBTENER LA DATA AAFIT, BBFIT, TRANSFORMACIONES Y OTROS PARA EL DATAFRAME

#Como el runid es identico para todos los datos en un mismo archivo, uso el primero que aparece en el dataframe
runID = int(list(str(data[0][ind_runid[0]]).split(" "))[0])

#Igual como el interactionID es el mismo para todos, asigno 1 si el archivo es "numu" y 2 si es "anumu"
if "anumu" in str(file):
    interactionID = 2
else:
    interactionID = 1
    
#Se requiere un dataframe donde iremos guardando cada fila de data obtenida
columnas = ['runID','frameID','trigger_counter','interactionID','aafit_azimut','aafit_zenit',
            'aafit_lambda','aafit_beta','bbfit_azimut','bbfit_zenit','bbfit_quality']
df_data1 = pd.DataFrame(columns=columnas)

#Ahora generamos un bucle para recorrer todo el archivo y usamos los indices
for i in range(len(ind_startev)):
    #Codigo para obtener los demas datos por cada evento y despues asignarlo a los hits
    #Divido la cadena en los valores que la componen para después extraer frameid y trigger_counter
    temprunid = list(data[0][ind_runid[i]].split(" "))
    tempmuon = list(data[0][ind_muon[i]].split(" "))
    tempaafit = list(data[0][ind_aafit[i]].split(" "))
    tempbbfit = list(data[0][ind_bbfit[i]].split(" "))
    #Extrayendo las variables frameid, trigger_counter de este renglon---> esta data si cambia ojo!!
    frameID = temprunid[1]; trigger_counter = temprunid [2]
    #Obteniendo y generando Datos para aafit
    aafit_azimut = math.atan2(float(tempaafit[3]),float(tempaafit[2]))
    aafit_zenit = math.acos(float(tempaafit[4]))
    aafit_lambda = tempaafit[-2]
    aafit_beta = tempaafit [-1]
    #Obteniendo y generando Datos para bbfit
    X = float(tempbbfit[2]); Y = float(tempbbfit[3]); Z = float(tempbbfit[4])
    #Hay que verificar si X o Y son nan y asignar el valor de bbfit_azimut
    if math.isnan(X):   bbfit_azimut = -3*math.pi
    elif math.isnan(Y): bbfit_azimut = -3*math.pi
    else: bbfit_azimut = math.atan2(Y,X)
    bbfit_zenit = math.acos(Z)
    bbfit_quality = float(tempbbfit[-1]) 
    #Añadimos la data obtenida y la generada al dataframe
    renglon = [runID, frameID, trigger_counter, interactionID,aafit_azimut, aafit_zenit,
               aafit_lambda,aafit_beta, bbfit_azimut,bbfit_zenit,bbfit_quality]
    df_data1.loc[i] = renglon
